# %% [markdown]
# <a href="https://colab.research.google.com/github/madara-tribe/ML_algorithms/blob/master/Pdcafield.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt
#import seaborn as sns
from keras import optimizers
## Import usual libraries
import tensorflow as tf
import keras, sys, time, warnings
from keras.models import *
from keras.layers import *
from keras import optimizers
from keras import backend
from datetime import datetime #DB
import gc #DB
from tqdm import tqdm
from sklearn.utils import shuffle
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import LearningRateScheduler, ReduceLROnPlateau
warnings.filterwarnings("ignore")



import tensorflow as tf
import sys, time, warnings
import keras as keras
from keras.models import *
from keras.layers import *
#from keras.utils import plot_model #DB
warnings.filterwarnings("ignore")


IMAGE_ORDERING =  "channels_last"



#Function to add 2 convolutional layers with the parameters passed to it
def conv2d_block(input_tensor, n_filters, kernel_size = 3, batchnorm = True, activation=True):
    #firt layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),
               kernel_initializer = 'he_normal', padding = 'same', data_format=IMAGE_ORDERING)(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    if activation:
        x = Activation('relu')(x)
    # second layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),
               kernel_initializer = 'he_normal', padding = 'same', data_format=IMAGE_ORDERING)(x)
    if batchnorm:
        x = BatchNormalization()(x)
    if activation:
        x = Activation('relu')(x)

    return x

# like UNET_v1 but with a Conv2D layer betweeb UpSampling2D aand Concatenate layers
def UNET_v2( nClasses, input_height, input_width, n_filters=16*2, dropout=0.1,
          batchnorm=True, activation=True):

    ## input_height and width must be devisible by 16 because maxpooling with filter size = (2,2) is operated 4 times,
    ## which makes the input_height and width 2^4 = 16 times smaller
    assert input_height%16 == 0
    assert input_width%16 == 0

    img_input = Input(shape=(input_height,input_width, 3)) ## Assume 224,224,3
    ## Downscaling

    ## Block 1: 64, 64
    c1 = conv2d_block(img_input, n_filters * 1, kernel_size = 3, batchnorm = batchnorm, activation=activation)
    c1 = conv2d_block(c1, n_filters * 1, kernel_size = 3, batchnorm = batchnorm, activation=activation)
    p1 = MaxPooling2D((2, 2))(c1)
    p1 = Dropout(dropout)(p1) # 112x112x64

    ## Block 2: 128, 128
    c2 = conv2d_block(p1, n_filters * 2, kernel_size = 3, batchnorm = batchnorm,  activation=activation)
    c2 = conv2d_block(c2, n_filters * 2, kernel_size = 3, batchnorm = batchnorm,  activation=activation)
    p2 = MaxPooling2D((2, 2))(c2)
    p2 = Dropout(dropout)(p2) # 56x56x128

    ## Block 3: 256, 256
    c3 = conv2d_block(p2, n_filters * 4, kernel_size = 3, batchnorm = batchnorm,  activation=activation)
    c3 = conv2d_block(c3, n_filters * 4, kernel_size = 3, batchnorm = batchnorm,  activation=activation)
    p3 = MaxPooling2D((2, 2))(c3)
    p3 = Dropout(dropout)(p3) # 28x28x256

    ## Block 4: 512, 512
    c4 = conv2d_block(p3, n_filters * 8, kernel_size = 3, batchnorm = batchnorm,  activation=activation)
    c4 = conv2d_block(c4, n_filters * 8, kernel_size = 3, batchnorm = batchnorm,  activation=activation)
    p4 = MaxPooling2D((2, 2))(c4)
    p4 = Dropout(dropout)(p4) # 14x14x512

    ## Block5: 1024, 1024
    c5 = conv2d_block(p4, n_filters = n_filters * 16, kernel_size = 3, batchnorm = batchnorm, activation=activation)
    c5 = conv2d_block(c5, n_filters = n_filters * 16, kernel_size = 3, batchnorm = batchnorm, activation=activation)
    p5 = Dropout(dropout)(c5) # 14x14x1024
    ## Upscaling

    ## Block6: 512, 512
    up6 = UpSampling2D(size=(2, 2),data_format=IMAGE_ORDERING, interpolation="bilinear")(p5) # 28x28x1024
    u6 = Conv2D(filters=n_filters*8, kernel_size=2, data_format=IMAGE_ORDERING,
                activation=None, padding="same", kernel_initializer="he_normal")(up6)
    m6 = Concatenate(axis=3)([u6, c4])
    m6 = BatchNormalization()(m6)
    c6 = conv2d_block(m6, n_filters * 8, kernel_size = 3, batchnorm = batchnorm, activation=activation)
    
    ## Block7: 256, 256
    up7 = UpSampling2D(size=(2, 2),data_format=IMAGE_ORDERING, interpolation="bilinear")(c6) #56x56x256
    u7 = Conv2D(filters=n_filters*4, kernel_size=2, data_format=IMAGE_ORDERING,
                activation=None, padding="same", kernel_initializer="he_normal")(up7)
    m7 = Concatenate(axis=3)([u7, c3])
    m7 = BatchNormalization()(m7)
    c7 = conv2d_block(m7, n_filters * 4, kernel_size = 3, batchnorm = batchnorm, activation=activation)
    
    ## Block8: 128, 128
    up8 = UpSampling2D(size=(2, 2),data_format=IMAGE_ORDERING, interpolation="bilinear")(c7) # 112x112x128
    u8  = Conv2D(filters=n_filters*2, kernel_size=2, data_format=IMAGE_ORDERING,
                activation=None, padding="same", kernel_initializer="he_normal")(up8)
    m8  = Concatenate(axis=3)([u8, c2])
    m8 = BatchNormalization()(m8)
    c8 = conv2d_block(m8, n_filters * 2, kernel_size = 3, batchnorm = batchnorm, activation=activation)
    
    ## Block9: 64, 64
    up9 = UpSampling2D(size=(2, 2),data_format=IMAGE_ORDERING, interpolation="bilinear")(c8) # 224x224x64
    u9  = Conv2D(filters=n_filters*1, kernel_size=2, data_format=IMAGE_ORDERING,
                activation=None, padding="same", kernel_initializer="he_normal")(up9)
    m9 = Concatenate(axis=3)([u9, c1])
    m9 = BatchNormalization()(m9)
    c9 = conv2d_block(m9, n_filters * 1, kernel_size = 3, batchnorm = batchnorm, activation=activation)
    
    ## Last layers
    c10 = Conv2D(filters=nClasses, kernel_size=1, data_format=IMAGE_ORDERING)(c9)
    o = (Activation("softmax"))(c10)
    model = Model(inputs=img_input, outputs=o)

    return model

N=160
HEIGHT = int(400-N)
WIDTH  = int(640-N)
print(HEIGHT, WIDTH)
N_CLASSES = 5

BATCH_SIZE = 2
EPOCHS = 100

weight_path='keras_model/fst.hdf5'
model_type = 2
model = UNET_v2(N_CLASSES, HEIGHT, WIDTH)
#model.load_weights(weight_path)
model.summary()
# Out:
# 240 480
# Model: "functional_9"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 240, 480, 3) 0
# __________________________________________________________________________________________________
# conv2d_132 (Conv2D)             (None, 240, 480, 32) 896         input_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_128 (BatchN (None, 240, 480, 32) 128         conv2d_132[0][0]
# __________________________________________________________________________________________________
# activation_116 (Activation)     (None, 240, 480, 32) 0           batch_normalization_128[0][0]
# __________________________________________________________________________________________________
# conv2d_133 (Conv2D)             (None, 240, 480, 32) 9248        activation_116[0][0]
# __________________________________________________________________________________________________
# batch_normalization_129 (BatchN (None, 240, 480, 32) 128         conv2d_133[0][0]
# __________________________________________________________________________________________________
# activation_117 (Activation)     (None, 240, 480, 32) 0           batch_normalization_129[0][0]
# __________________________________________________________________________________________________
# conv2d_134 (Conv2D)             (None, 240, 480, 32) 9248        activation_117[0][0]
# __________________________________________________________________________________________________
# batch_normalization_130 (BatchN (None, 240, 480, 32) 128         conv2d_134[0][0]
# __________________________________________________________________________________________________
# activation_118 (Activation)     (None, 240, 480, 32) 0           batch_normalization_130[0][0]
# __________________________________________________________________________________________________
# conv2d_135 (Conv2D)             (None, 240, 480, 32) 9248        activation_118[0][0]
# __________________________________________________________________________________________________
# batch_normalization_131 (BatchN (None, 240, 480, 32) 128         conv2d_135[0][0]
# __________________________________________________________________________________________________
# activation_119 (Activation)     (None, 240, 480, 32) 0           batch_normalization_131[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 120, 240, 32) 0           activation_119[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 120, 240, 32) 0           max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_136 (Conv2D)             (None, 120, 240, 64) 18496       dropout_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_132 (BatchN (None, 120, 240, 64) 256         conv2d_136[0][0]
# __________________________________________________________________________________________________
# activation_120 (Activation)     (None, 120, 240, 64) 0           batch_normalization_132[0][0]
# __________________________________________________________________________________________________
# conv2d_137 (Conv2D)             (None, 120, 240, 64) 36928       activation_120[0][0]
# __________________________________________________________________________________________________
# batch_normalization_133 (BatchN (None, 120, 240, 64) 256         conv2d_137[0][0]
# __________________________________________________________________________________________________
# activation_121 (Activation)     (None, 120, 240, 64) 0           batch_normalization_133[0][0]
# __________________________________________________________________________________________________
# conv2d_138 (Conv2D)             (None, 120, 240, 64) 36928       activation_121[0][0]
# __________________________________________________________________________________________________
# batch_normalization_134 (BatchN (None, 120, 240, 64) 256         conv2d_138[0][0]
# __________________________________________________________________________________________________
# activation_122 (Activation)     (None, 120, 240, 64) 0           batch_normalization_134[0][0]
# __________________________________________________________________________________________________
# conv2d_139 (Conv2D)             (None, 120, 240, 64) 36928       activation_122[0][0]
# __________________________________________________________________________________________________
# batch_normalization_135 (BatchN (None, 120, 240, 64) 256         conv2d_139[0][0]
# __________________________________________________________________________________________________
# activation_123 (Activation)     (None, 120, 240, 64) 0           batch_normalization_135[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, 60, 120, 64)  0           activation_123[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 60, 120, 64)  0           max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_140 (Conv2D)             (None, 60, 120, 128) 73856       dropout_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_136 (BatchN (None, 60, 120, 128) 512         conv2d_140[0][0]
# __________________________________________________________________________________________________
# activation_124 (Activation)     (None, 60, 120, 128) 0           batch_normalization_136[0][0]
# __________________________________________________________________________________________________
# conv2d_141 (Conv2D)             (None, 60, 120, 128) 147584      activation_124[0][0]
# __________________________________________________________________________________________________
# batch_normalization_137 (BatchN (None, 60, 120, 128) 512         conv2d_141[0][0]
# __________________________________________________________________________________________________
# activation_125 (Activation)     (None, 60, 120, 128) 0           batch_normalization_137[0][0]
# __________________________________________________________________________________________________
# conv2d_142 (Conv2D)             (None, 60, 120, 128) 147584      activation_125[0][0]
# __________________________________________________________________________________________________
# batch_normalization_138 (BatchN (None, 60, 120, 128) 512         conv2d_142[0][0]
# __________________________________________________________________________________________________
# activation_126 (Activation)     (None, 60, 120, 128) 0           batch_normalization_138[0][0]
# __________________________________________________________________________________________________
# conv2d_143 (Conv2D)             (None, 60, 120, 128) 147584      activation_126[0][0]
# __________________________________________________________________________________________________
# batch_normalization_139 (BatchN (None, 60, 120, 128) 512         conv2d_143[0][0]
# __________________________________________________________________________________________________
# activation_127 (Activation)     (None, 60, 120, 128) 0           batch_normalization_139[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_18 (MaxPooling2D) (None, 30, 60, 128)  0           activation_127[0][0]
# __________________________________________________________________________________________________
# dropout_22 (Dropout)            (None, 30, 60, 128)  0           max_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_144 (Conv2D)             (None, 30, 60, 256)  295168      dropout_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_140 (BatchN (None, 30, 60, 256)  1024        conv2d_144[0][0]
# __________________________________________________________________________________________________
# activation_128 (Activation)     (None, 30, 60, 256)  0           batch_normalization_140[0][0]
# __________________________________________________________________________________________________
# conv2d_145 (Conv2D)             (None, 30, 60, 256)  590080      activation_128[0][0]
# __________________________________________________________________________________________________
# batch_normalization_141 (BatchN (None, 30, 60, 256)  1024        conv2d_145[0][0]
# __________________________________________________________________________________________________
# activation_129 (Activation)     (None, 30, 60, 256)  0           batch_normalization_141[0][0]
# __________________________________________________________________________________________________
# conv2d_146 (Conv2D)             (None, 30, 60, 256)  590080      activation_129[0][0]
# __________________________________________________________________________________________________
# batch_normalization_142 (BatchN (None, 30, 60, 256)  1024        conv2d_146[0][0]
# __________________________________________________________________________________________________
# activation_130 (Activation)     (None, 30, 60, 256)  0           batch_normalization_142[0][0]
# __________________________________________________________________________________________________
# conv2d_147 (Conv2D)             (None, 30, 60, 256)  590080      activation_130[0][0]
# __________________________________________________________________________________________________
# batch_normalization_143 (BatchN (None, 30, 60, 256)  1024        conv2d_147[0][0]
# __________________________________________________________________________________________________
# activation_131 (Activation)     (None, 30, 60, 256)  0           batch_normalization_143[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_19 (MaxPooling2D) (None, 15, 30, 256)  0           activation_131[0][0]
# __________________________________________________________________________________________________
# dropout_23 (Dropout)            (None, 15, 30, 256)  0           max_pooling2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_148 (Conv2D)             (None, 15, 30, 512)  1180160     dropout_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_144 (BatchN (None, 15, 30, 512)  2048        conv2d_148[0][0]
# __________________________________________________________________________________________________
# activation_132 (Activation)     (None, 15, 30, 512)  0           batch_normalization_144[0][0]
# __________________________________________________________________________________________________
# conv2d_149 (Conv2D)             (None, 15, 30, 512)  2359808     activation_132[0][0]
# __________________________________________________________________________________________________
# batch_normalization_145 (BatchN (None, 15, 30, 512)  2048        conv2d_149[0][0]
# __________________________________________________________________________________________________
# activation_133 (Activation)     (None, 15, 30, 512)  0           batch_normalization_145[0][0]
# __________________________________________________________________________________________________
# conv2d_150 (Conv2D)             (None, 15, 30, 512)  2359808     activation_133[0][0]
# __________________________________________________________________________________________________
# batch_normalization_146 (BatchN (None, 15, 30, 512)  2048        conv2d_150[0][0]
# __________________________________________________________________________________________________
# activation_134 (Activation)     (None, 15, 30, 512)  0           batch_normalization_146[0][0]
# __________________________________________________________________________________________________
# conv2d_151 (Conv2D)             (None, 15, 30, 512)  2359808     activation_134[0][0]
# __________________________________________________________________________________________________
# batch_normalization_147 (BatchN (None, 15, 30, 512)  2048        conv2d_151[0][0]
# __________________________________________________________________________________________________
# activation_135 (Activation)     (None, 15, 30, 512)  0           batch_normalization_147[0][0]
# __________________________________________________________________________________________________
# dropout_24 (Dropout)            (None, 15, 30, 512)  0           activation_135[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_16 (UpSampling2D) (None, 30, 60, 512)  0           dropout_24[0][0]
# __________________________________________________________________________________________________
# conv2d_152 (Conv2D)             (None, 30, 60, 256)  524544      up_sampling2d_16[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 30, 60, 512)  0           conv2d_152[0][0]
#                                                                  activation_131[0][0]
# __________________________________________________________________________________________________
# batch_normalization_148 (BatchN (None, 30, 60, 512)  2048        concatenate_16[0][0]
# __________________________________________________________________________________________________
# conv2d_153 (Conv2D)             (None, 30, 60, 256)  1179904     batch_normalization_148[0][0]
# __________________________________________________________________________________________________
# batch_normalization_149 (BatchN (None, 30, 60, 256)  1024        conv2d_153[0][0]
# __________________________________________________________________________________________________
# activation_136 (Activation)     (None, 30, 60, 256)  0           batch_normalization_149[0][0]
# __________________________________________________________________________________________________
# conv2d_154 (Conv2D)             (None, 30, 60, 256)  590080      activation_136[0][0]
# __________________________________________________________________________________________________
# batch_normalization_150 (BatchN (None, 30, 60, 256)  1024        conv2d_154[0][0]
# __________________________________________________________________________________________________
# activation_137 (Activation)     (None, 30, 60, 256)  0           batch_normalization_150[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_17 (UpSampling2D) (None, 60, 120, 256) 0           activation_137[0][0]
# __________________________________________________________________________________________________
# conv2d_155 (Conv2D)             (None, 60, 120, 128) 131200      up_sampling2d_17[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 60, 120, 256) 0           conv2d_155[0][0]
#                                                                  activation_127[0][0]
# __________________________________________________________________________________________________
# batch_normalization_151 (BatchN (None, 60, 120, 256) 1024        concatenate_17[0][0]
# __________________________________________________________________________________________________
# conv2d_156 (Conv2D)             (None, 60, 120, 128) 295040      batch_normalization_151[0][0]
# __________________________________________________________________________________________________
# batch_normalization_152 (BatchN (None, 60, 120, 128) 512         conv2d_156[0][0]
# __________________________________________________________________________________________________
# activation_138 (Activation)     (None, 60, 120, 128) 0           batch_normalization_152[0][0]
# __________________________________________________________________________________________________
# conv2d_157 (Conv2D)             (None, 60, 120, 128) 147584      activation_138[0][0]
# __________________________________________________________________________________________________
# batch_normalization_153 (BatchN (None, 60, 120, 128) 512         conv2d_157[0][0]
# __________________________________________________________________________________________________
# activation_139 (Activation)     (None, 60, 120, 128) 0           batch_normalization_153[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_18 (UpSampling2D) (None, 120, 240, 128 0           activation_139[0][0]
# __________________________________________________________________________________________________
# conv2d_158 (Conv2D)             (None, 120, 240, 64) 32832       up_sampling2d_18[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 120, 240, 128 0           conv2d_158[0][0]
#                                                                  activation_123[0][0]
# __________________________________________________________________________________________________
# batch_normalization_154 (BatchN (None, 120, 240, 128 512         concatenate_18[0][0]
# __________________________________________________________________________________________________
# conv2d_159 (Conv2D)             (None, 120, 240, 64) 73792       batch_normalization_154[0][0]
# __________________________________________________________________________________________________
# batch_normalization_155 (BatchN (None, 120, 240, 64) 256         conv2d_159[0][0]
# __________________________________________________________________________________________________
# activation_140 (Activation)     (None, 120, 240, 64) 0           batch_normalization_155[0][0]
# __________________________________________________________________________________________________
# conv2d_160 (Conv2D)             (None, 120, 240, 64) 36928       activation_140[0][0]
# __________________________________________________________________________________________________
# batch_normalization_156 (BatchN (None, 120, 240, 64) 256         conv2d_160[0][0]
# __________________________________________________________________________________________________
# activation_141 (Activation)     (None, 120, 240, 64) 0           batch_normalization_156[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_19 (UpSampling2D) (None, 240, 480, 64) 0           activation_141[0][0]
# __________________________________________________________________________________________________
# conv2d_161 (Conv2D)             (None, 240, 480, 32) 8224        up_sampling2d_19[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 240, 480, 64) 0           conv2d_161[0][0]
#                                                                  activation_119[0][0]
# __________________________________________________________________________________________________
# batch_normalization_157 (BatchN (None, 240, 480, 64) 256         concatenate_19[0][0]
# __________________________________________________________________________________________________
# conv2d_162 (Conv2D)             (None, 240, 480, 32) 18464       batch_normalization_157[0][0]
# __________________________________________________________________________________________________
# batch_normalization_158 (BatchN (None, 240, 480, 32) 128         conv2d_162[0][0]
# __________________________________________________________________________________________________
# activation_142 (Activation)     (None, 240, 480, 32) 0           batch_normalization_158[0][0]
# __________________________________________________________________________________________________
# conv2d_163 (Conv2D)             (None, 240, 480, 32) 9248        activation_142[0][0]
# __________________________________________________________________________________________________
# batch_normalization_159 (BatchN (None, 240, 480, 32) 128         conv2d_163[0][0]
# __________________________________________________________________________________________________
# activation_143 (Activation)     (None, 240, 480, 32) 0           batch_normalization_159[0][0]
# __________________________________________________________________________________________________
# conv2d_164 (Conv2D)             (None, 240, 480, 5)  165         activation_143[0][0]
# __________________________________________________________________________________________________
# activation_144 (Activation)     (None, 240, 480, 5)  0           conv2d_164[0][0]
# ==================================================================================================
# Total params: 14,071,077
# Trainable params: 14,059,301
# Non-trainable params: 11,776
# __________________________________________________________________________________________________

# %%
path='/content/drive/MyDrive/4cls/'
dir_train_img=path+'train'
dir_train_seg=path+'anno'
dir_valid_img = path+'val'
dir_valid_seg = path+'val_anno'




def flipud_image(X, Y):
    Xflip =np.array([img[::-1] for img in X])
    Yflip =np.array([img[::-1] for img in Y])
    return Xflip, Yflip
    
def fliplr_image(X, Y):
    Xflip =np.array([img[:, ::-1] for img in X])
    Yflip =np.array([img[:, ::-1] for img in Y])
    return Xflip, Yflip

def salt(img):
    row,col,ch = img.shape
    s_vs_p = 0.5
    amount = 0.004
    sp_img = img.copy()
    # pepper
    num_pepper = np.ceil(amount* img.size * (1. - s_vs_p))
    coords = [np.random.randint(0, i-1 , int(num_pepper)) for i in img.shape]
    sp_img[coords[:-1]] = (0,0,0)
    return sp_img
	
	
def channel_shift(img, value):
    value = int(random.uniform(-value, value))
    img = img + value
    img[:,:,:][img[:,:,:]>255]  = 255
    img[:,:,:][img[:,:,:]<0]  = 0
    #img = img.astype(np.uint8)
    return img

def contrast(img, gamma = 0.5):
    gamma_cvt = np.zeros((256,1),dtype = 'uint8')
 
    for i in range(256):
        gamma_cvt[i][0] = 255 * (float(i)/255) ** (1.0/gamma)
    return cv2.LUT(img, gamma_cvt)

def sift_angle(image, y_move_ratio=0, x_move_ratio=0, angle_ratio=float(np.pi/60)):
    h, w, _ = np.shape(image)
    size = tuple(np.array([w, h]))
    print(size)
    #np.pi=3.141592653589793
    rad=angle_ratio
    move_x = x_move_ratio
    move_y = w * y_move_ratio

    matrix = [[np.cos(rad), -1 * np.sin(rad), move_x],
                   [np.sin(rad), np.cos(rad), move_y]]

    affine_matrix = np.float32(matrix)
    chage_angle = cv2.warpAffine(image, affine_matrix, size, flags=cv2.INTER_LINEAR)
    return chage_angle

def clahe(bgr):
    #plt.imshow(bgr),plt.show()
    lab = cv2.cvtColor(bgr, cv2.COLOR_BGR2LAB)
    #plt.imshow(lab),plt.show()
    lab_planes = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=6.0,tileGridSize=(8,8))
    lab_planes[0] = clahe.apply(lab_planes[0])
    lab = cv2.merge(lab_planes)
    return cv2.cvtColor(lab, cv2.COLOR_LAB2BGR)


def ContrastNormalizeImageArr(path, H, W, gamma=1.8):
    NORM_FACTOR = 255
    img = cv2.imread(path, 1)
    img = contrast(img, gamma = gamma)
    img = cv2.resize(img, (H, W), interpolation=cv2.INTER_NEAREST)
    img = img.astype(np.float32)
    img = img/NORM_FACTOR
    return img

def NormalizeImageArr(path, H, W, aug_type=None):
    aug_type = aug_type
    NORM_FACTOR = 255
    img = cv2.imread(path, 1)
    img = cv2.resize(img, (H, W), interpolation=cv2.INTER_NEAREST)
    if img.mean()<80:
        img = clahe(img)

    if aug_type == 'pepper':
        img = salt(img)
    elif aug_type == 'sift':
        img = channel_shift(img, 60)
    else:
        pass
    img = img.astype(np.float32)
    img = img/NORM_FACTOR
    return img

def LoadSegmentationArr( path , nClasses,  width ,height):
    seg_labels = np.zeros((height, width, nClasses))
    img = cv2.imread(path, 1)
    img = cv2.resize(img, (width, height), interpolation=cv2.INTER_NEAREST)
    img = img[:, : , 0]
    for c in range(nClasses):
        seg_labels[: , : , c ] = (img == c ).astype(int)
    return seg_labels

print('train load')
train_images = os.listdir(dir_train_img)
train_images.sort()
train_segmentations  = os.listdir(dir_train_seg)
train_segmentations.sort()
X_train, Y_train=[], []

for im , seg in tqdm(zip(train_images[:25], train_segmentations[:25])):
    X_train.append(NormalizeImageArr(os.path.join(dir_train_img,im), WIDTH, HEIGHT, aug_type=None))
    Y_train.append(LoadSegmentationArr( os.path.join(dir_train_seg,seg), N_CLASSES, WIDTH, HEIGHT)  )

X_train, Y_train = np.array(X_train), np.array(Y_train)
#X1, Y1 = fliplr_image(X_train, Y_train)
#X_train = np.vstack([X_train, X1])

#X_train, Y_train = shuffle(X_train, Y_train)
print(X_train.shape,Y_train.shape)
print(X_train.max(), X_train.min())

# In[13]:


# load validation images
valid_images = os.listdir(dir_valid_img)
valid_images.sort()
valid_segmentations  = os.listdir(dir_valid_seg)
valid_segmentations.sort()
X_valid, Y_valid = [], []

for im , seg in tqdm(zip(valid_images,valid_segmentations)):
    X_valid.append(NormalizeImageArr(os.path.join(dir_valid_img,im), WIDTH, HEIGHT) )
    Y_valid.append(LoadSegmentationArr( os.path.join(dir_valid_seg,seg) , N_CLASSES, WIDTH, HEIGHT))


X_valid, Y_valid = np.array(X_valid), np.array(Y_valid)
#Xv1, Yv1 = fliplr_image(X_valid, Y_valid)
#X_valid = np.vstack([X_valid, Xv1])
#Y_valid = np.vstack([Y_valid, Yv1])
print(X_valid.shape,Y_valid.shape)
print(X_valid.max(),X_valid.min())
plt.imshow(X_train[5]),plt.show()
plt.imshow(X_valid[2]),plt.show()
# Out:
# 0it [00:00, ?it/s]
# 2it [00:00, 14.90it/s]
# train load
# 4it [00:00, 14.66it/s]
# 6it [00:00, 14.12it/s]
# 8it [00:00, 14.19it/s]
# 10it [00:00, 14.59it/s]
# 12it [00:00, 14.65it/s]
# 14it [00:00, 14.82it/s]
# 16it [00:01, 14.69it/s]
# 18it [00:01, 14.57it/s]
# 20it [00:01, 14.55it/s]
# 22it [00:01, 14.36it/s]
# 25it [00:01, 14.45it/s]
#
# 0it [00:00, ?it/s]
# 2it [00:00, 14.95it/s]
# (25, 240, 480, 3) (25, 240, 480, 5)
# 1.0 0.0
# 4it [00:00, 14.62it/s]
# 6it [00:00, 14.12it/s]
# 8it [00:00, 14.09it/s]
# 10it [00:00, 13.93it/s]
# (10, 240, 480, 3) (10, 240, 480, 5)
# 1.0 0.0
# (<matplotlib.image.AxesImage at 0x7fb84917f2b0>, None)

# %%
def step_decay_schedule(initial_lr=1e-3, decay_factor=0.75, step_size=10):
    '''
    Wrapper function to create a LearningRateScheduler with step decay schedule.
    '''
    def schedule(epoch):
        return initial_lr * (decay_factor ** np.floor(epoch/step_size))
    
    return LearningRateScheduler(schedule)


checkpoint_path = "train_ck/cp-{epoch:04d}.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
 
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    checkpoint_path, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True, period=1)


lr_scheduler = step_decay_schedule(initial_lr=0.001, decay_factor=0.75, step_size=2)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, verbose=1)
callback = [lr_scheduler]

adam=optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0)
model.compile(loss='categorical_crossentropy',
              optimizer=adam,
              metrics=['accuracy'])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
startTime1 = datetime.now() #DB
hist1 = model.fit(X_train,Y_train, validation_data=(X_valid,Y_valid), 
                  batch_size=2,epochs=200)
endTime1 = datetime.now()
diff1 = endTime1 - startTime1
print("\n")
print("Elapsed time for Keras training (s): ", diff1.total_seconds())
print("\n")

for key in ["loss", "val_loss"]:
    plt.plot(hist1.history[key],label=key)
plt.legend()

print("\nEnd of UNET training\n")
# Out:
# Epoch 1/200
# 13/13 [==============================] - ETA: 0s - loss: 1.6905 - accuracy: 0.5283WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0066s vs `on_test_batch_end` time: 0.0212s). Check your callbacks.
# 13/13 [==============================] - 2s 163ms/step - loss: 1.6905 - accuracy: 0.5283 - val_loss: 15.1110 - val_accuracy: 0.0563
# Epoch 2/200
# 13/13 [==============================] - 1s 106ms/step - loss: 1.0569 - accuracy: 0.8282 - val_loss: 12.7652 - val_accuracy: 0.2080
# Epoch 3/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.8139 - accuracy: 0.8493 - val_loss: 13.4490 - val_accuracy: 0.1653
# Epoch 4/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.7312 - accuracy: 0.8560 - val_loss: 12.7207 - val_accuracy: 0.2089
# Epoch 5/200
# 13/13 [==============================] - 1s 107ms/step - loss: 0.6407 - accuracy: 0.8673 - val_loss: 12.4052 - val_accuracy: 0.2097
# Epoch 6/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.5406 - accuracy: 0.8735 - val_loss: 10.7221 - val_accuracy: 0.2333
# Epoch 7/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.5002 - accuracy: 0.8815 - val_loss: 11.7322 - val_accuracy: 0.2209
# Epoch 8/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.4495 - accuracy: 0.8813 - val_loss: 4.8609 - val_accuracy: 0.2835
# Epoch 9/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.4244 - accuracy: 0.8789 - val_loss: 5.4115 - val_accuracy: 0.2744
# Epoch 10/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.3940 - accuracy: 0.8887 - val_loss: 6.0606 - val_accuracy: 0.5386
# Epoch 11/200
# 13/13 [==============================] - 1s 107ms/step - loss: 0.3882 - accuracy: 0.8948 - val_loss: 7.2985 - val_accuracy: 0.3725
# Epoch 12/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.3587 - accuracy: 0.8963 - val_loss: 5.1837 - val_accuracy: 0.5417
# Epoch 13/200
# 13/13 [==============================] - 1s 107ms/step - loss: 0.3583 - accuracy: 0.8903 - val_loss: 6.1730 - val_accuracy: 0.5004
# Epoch 14/200
# 13/13 [==============================] - 1s 107ms/step - loss: 0.3410 - accuracy: 0.8998 - val_loss: 2.7034 - val_accuracy: 0.6799
# Epoch 15/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.3127 - accuracy: 0.9037 - val_loss: 1.5412 - val_accuracy: 0.7823
# Epoch 16/200
# 13/13 [==============================] - 1s 107ms/step - loss: 0.2918 - accuracy: 0.9092 - val_loss: 3.2178 - val_accuracy: 0.6636
# Epoch 17/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.2914 - accuracy: 0.9103 - val_loss: 0.7555 - val_accuracy: 0.8403
# Epoch 18/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.2885 - accuracy: 0.9095 - val_loss: 2.1376 - val_accuracy: 0.7143
# Epoch 19/200
# 13/13 [==============================] - 1s 105ms/step - loss: 0.2775 - accuracy: 0.9132 - val_loss: 1.5323 - val_accuracy: 0.7783
# Epoch 20/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.2805 - accuracy: 0.9074 - val_loss: 2.6816 - val_accuracy: 0.7140
# Epoch 21/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.2706 - accuracy: 0.9131 - val_loss: 1.2059 - val_accuracy: 0.7946
# Epoch 22/200
# 13/13 [==============================] - 1s 107ms/step - loss: 0.2472 - accuracy: 0.9216 - val_loss: 0.8601 - val_accuracy: 0.8411
# Epoch 23/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.2719 - accuracy: 0.9086 - val_loss: 0.8284 - val_accuracy: 0.8805
# Epoch 24/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.2444 - accuracy: 0.9176 - val_loss: 0.5607 - val_accuracy: 0.8626
# Epoch 25/200
# 13/13 [==============================] - 1s 107ms/step - loss: 0.2370 - accuracy: 0.9210 - val_loss: 0.5481 - val_accuracy: 0.8842
# Epoch 26/200
# 13/13 [==============================] - 1s 107ms/step - loss: 0.2422 - accuracy: 0.9190 - val_loss: 0.4672 - val_accuracy: 0.8745
# Epoch 27/200
# 13/13 [==============================] - 1s 107ms/step - loss: 0.2456 - accuracy: 0.9148 - val_loss: 0.6401 - val_accuracy: 0.8840
# Epoch 28/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.2578 - accuracy: 0.9124 - val_loss: 0.8664 - val_accuracy: 0.8533
# Epoch 29/200
# 13/13 [==============================] - 1s 107ms/step - loss: 0.2171 - accuracy: 0.9269 - val_loss: 0.5814 - val_accuracy: 0.8914
# Epoch 30/200
# 13/13 [==============================] - 1s 107ms/step - loss: 0.2155 - accuracy: 0.9294 - val_loss: 0.4301 - val_accuracy: 0.8866
# Epoch 31/200
# 13/13 [==============================] - 1s 107ms/step - loss: 0.2266 - accuracy: 0.9234 - val_loss: 0.5383 - val_accuracy: 0.8886
# Epoch 32/200
# 13/13 [==============================] - 1s 107ms/step - loss: 0.2129 - accuracy: 0.9292 - val_loss: 0.3355 - val_accuracy: 0.9055
# Epoch 33/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.2168 - accuracy: 0.9264 - val_loss: 0.3293 - val_accuracy: 0.9051
# Epoch 34/200
# 13/13 [==============================] - 1s 105ms/step - loss: 0.2002 - accuracy: 0.9320 - val_loss: 0.3533 - val_accuracy: 0.9131
# Epoch 35/200
# 13/13 [==============================] - 1s 107ms/step - loss: 0.1951 - accuracy: 0.9358 - val_loss: 0.4723 - val_accuracy: 0.8928
# Epoch 36/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.1904 - accuracy: 0.9352 - val_loss: 0.3729 - val_accuracy: 0.8840
# Epoch 37/200
# 13/13 [==============================] - 1s 107ms/step - loss: 0.1846 - accuracy: 0.9366 - val_loss: 0.4155 - val_accuracy: 0.8874
# Epoch 38/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.1714 - accuracy: 0.9402 - val_loss: 0.3464 - val_accuracy: 0.8967
# Epoch 39/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.1681 - accuracy: 0.9432 - val_loss: 0.4888 - val_accuracy: 0.8599
# Epoch 40/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.2131 - accuracy: 0.9222 - val_loss: 0.6161 - val_accuracy: 0.8710
# Epoch 41/200
# 13/13 [==============================] - 1s 107ms/step - loss: 0.2158 - accuracy: 0.9223 - val_loss: 0.4430 - val_accuracy: 0.8943
# Epoch 42/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.1927 - accuracy: 0.9306 - val_loss: 0.6046 - val_accuracy: 0.8664
# Epoch 43/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.1786 - accuracy: 0.9394 - val_loss: 0.6587 - val_accuracy: 0.8811
# Epoch 44/200
# 13/13 [==============================] - 1s 107ms/step - loss: 0.1714 - accuracy: 0.9403 - val_loss: 0.7007 - val_accuracy: 0.8730
# Epoch 45/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.1680 - accuracy: 0.9410 - val_loss: 0.5154 - val_accuracy: 0.8857
# Epoch 46/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.1520 - accuracy: 0.9491 - val_loss: 0.5063 - val_accuracy: 0.8860
# Epoch 47/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.1440 - accuracy: 0.9513 - val_loss: 0.4111 - val_accuracy: 0.8889
# Epoch 48/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.1460 - accuracy: 0.9475 - val_loss: 0.4528 - val_accuracy: 0.8753
# Epoch 49/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.1863 - accuracy: 0.9342 - val_loss: 0.6956 - val_accuracy: 0.8202
# Epoch 50/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.2062 - accuracy: 0.9261 - val_loss: 0.8420 - val_accuracy: 0.8182
# Epoch 51/200
# 13/13 [==============================] - 1s 107ms/step - loss: 0.1719 - accuracy: 0.9395 - val_loss: 0.5371 - val_accuracy: 0.8255
# Epoch 52/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.1723 - accuracy: 0.9374 - val_loss: 0.5258 - val_accuracy: 0.8666
# Epoch 53/200
# 13/13 [==============================] - 1s 107ms/step - loss: 0.1657 - accuracy: 0.9402 - val_loss: 0.5170 - val_accuracy: 0.8652
# Epoch 54/200
# 13/13 [==============================] - 1s 107ms/step - loss: 0.1485 - accuracy: 0.9475 - val_loss: 0.4500 - val_accuracy: 0.8967
# Epoch 55/200
# 13/13 [==============================] - 1s 107ms/step - loss: 0.1291 - accuracy: 0.9550 - val_loss: 0.4871 - val_accuracy: 0.8812
# Epoch 56/200
# 13/13 [==============================] - 1s 107ms/step - loss: 0.1256 - accuracy: 0.9555 - val_loss: 0.3318 - val_accuracy: 0.9072
# Epoch 57/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.1232 - accuracy: 0.9564 - val_loss: 0.3719 - val_accuracy: 0.8962
# Epoch 58/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.1222 - accuracy: 0.9575 - val_loss: 0.4049 - val_accuracy: 0.8835
# Epoch 59/200
# 13/13 [==============================] - 1s 107ms/step - loss: 0.1213 - accuracy: 0.9577 - val_loss: 0.4195 - val_accuracy: 0.8715
# Epoch 60/200
# 13/13 [==============================] - 1s 107ms/step - loss: 0.1127 - accuracy: 0.9614 - val_loss: 0.4243 - val_accuracy: 0.8789
# Epoch 61/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.1196 - accuracy: 0.9573 - val_loss: 0.3249 - val_accuracy: 0.8966
# Epoch 62/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.1178 - accuracy: 0.9585 - val_loss: 0.3751 - val_accuracy: 0.8959
# Epoch 63/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.1092 - accuracy: 0.9622 - val_loss: 0.4698 - val_accuracy: 0.8825
# Epoch 64/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.1166 - accuracy: 0.9615 - val_loss: 0.3151 - val_accuracy: 0.9113
# Epoch 65/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.1165 - accuracy: 0.9593 - val_loss: 0.4219 - val_accuracy: 0.8947
# Epoch 66/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.1135 - accuracy: 0.9593 - val_loss: 0.3309 - val_accuracy: 0.9065
# Epoch 67/200
# 13/13 [==============================] - 1s 107ms/step - loss: 0.1050 - accuracy: 0.9626 - val_loss: 0.4057 - val_accuracy: 0.8903
# Epoch 68/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.1038 - accuracy: 0.9623 - val_loss: 0.3263 - val_accuracy: 0.9033
# Epoch 69/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.0939 - accuracy: 0.9673 - val_loss: 0.3635 - val_accuracy: 0.8885
# Epoch 70/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.0913 - accuracy: 0.9684 - val_loss: 0.3412 - val_accuracy: 0.9013
# Epoch 71/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.0910 - accuracy: 0.9672 - val_loss: 0.3401 - val_accuracy: 0.9066
# Epoch 72/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.0886 - accuracy: 0.9694 - val_loss: 0.2901 - val_accuracy: 0.9093
# Epoch 73/200
# 13/13 [==============================] - 1s 107ms/step - loss: 0.0902 - accuracy: 0.9685 - val_loss: 0.3141 - val_accuracy: 0.9046
# Epoch 74/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.0919 - accuracy: 0.9682 - val_loss: 0.3976 - val_accuracy: 0.8699
# Epoch 75/200
# 13/13 [==============================] - 1s 107ms/step - loss: 0.1051 - accuracy: 0.9629 - val_loss: 0.3269 - val_accuracy: 0.9015
# Epoch 76/200
# 13/13 [==============================] - 1s 107ms/step - loss: 0.1111 - accuracy: 0.9611 - val_loss: 0.3230 - val_accuracy: 0.9050
# Epoch 77/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.1038 - accuracy: 0.9632 - val_loss: 0.9419 - val_accuracy: 0.8084
# Epoch 78/200
# 13/13 [==============================] - 1s 105ms/step - loss: 0.0986 - accuracy: 0.9649 - val_loss: 0.5236 - val_accuracy: 0.8519
# Epoch 79/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.0884 - accuracy: 0.9688 - val_loss: 0.3915 - val_accuracy: 0.8890
# Epoch 80/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.1222 - accuracy: 0.9577 - val_loss: 0.4529 - val_accuracy: 0.8742
# Epoch 81/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.1035 - accuracy: 0.9644 - val_loss: 0.4223 - val_accuracy: 0.8875
# Epoch 82/200
# 13/13 [==============================] - 1s 106ms/step - loss: 0.1262 - accuracy: 0.9547 - val_loss: 0.9442 - val_accuracy: 0.7800
# Epoch 83/200
# 13/13 [==============================] - 1s 107ms/step - loss: 0.1371 - accuracy: 0.9506 - val_loss: 2.4830 - val_accuracy: 0.6121
# Epoch 84/200
# 13/13 [==============================] - 1s 107ms/step - loss: 0.1414 - accuracy: 0.9497 - val_loss: 1.4361 - val_accuracy: 0.6937
# Epoch 85/200
# 12/13 [==========================>...] - ETA: 0s - loss: 0.1149 - accuracy: 0.9580

# %%
# names of classes
CLASS_NAMES = ("None", "Sky",
               "Wall",
               "Pole",
               "Road",
               "Sidewalk",
               "Vegetation",
               "Sign",
               "Fence",
               "vehicle",
               "Pedestrian")


EPOCHS = 200


#######################################################################################################

# colors for segmented classes
colorB = [128, 232, 70, 156, 153, 153,  30,   0,  35, 152, 180,  60,   0, 142, 70, 100, 100, 230,  32]
colorG = [ 64,  35, 70, 102, 153, 153, 170, 220, 142, 251, 130,  20,   0,   0,  0,  60,  80,   0,  11]
colorR = [128, 244, 70, 102, 190, 153, 250, 220, 107, 152,  70, 220, 255,   0,  0,   0,   0,   0, 119]
CLASS_COLOR = list()
for i in range(0, 19):
    CLASS_COLOR.append([colorR[i], colorG[i], colorB[i]])
COLORS = np.array(CLASS_COLOR, dtype="float32")


def give_color_to_seg_img(seg,n_classes):
    if len(seg.shape)==3:
        seg = seg[:,:,0]
    seg_img = np.zeros( (seg.shape[0],seg.shape[1],3) ).astype('float')
    #colors = sns.color_palette("hls", n_classes) #DB
    colors = COLORS #DB
    for c in range(n_classes):
        segc = (seg == c)
        seg_img[:,:,0] += (segc*( colors[c][0]/255.0 ))
        seg_img[:,:,1] += (segc*( colors[c][1]/255.0 ))
        seg_img[:,:,2] += (segc*( colors[c][2]/255.0 ))

    return(seg_img)

def IoU(Yi,y_predi):
    ## mean Intersection over Union
    ## Mean IoU = TP/(FN + TP + FP)
    IoUs = []
    Nclass = int(np.max(Yi)) + 1
    for c in range(Nclass):
        TP = np.sum( (Yi == c)&(y_predi == c))
        FP = np.sum( (Yi != c)&(y_predi == c))
        FN = np.sum( (Yi == c)&(y_predi != c))
        IoU = TP/float(TP + FP + FN)
        #print("class {:02.0f}: #TP={:7.0f}, #FP={:7.0f}, #FN={:7.0f}, IoU={:4.3f}".format(c,TP,FP,FN,IoU))
        print("class (%2d) %12.12s: #TP=%7.0f, #FP=%7.0f, #FN=%7.0f, IoU=%4.3f" % (c, CLASS_NAMES[c],TP,FP,FN,IoU))
        IoUs.append(IoU)
    mIoU = np.mean(IoUs)
    print("_________________")
    print("Mean IoU: {:4.3f}".format(mIoU))
    return


def get_images_and_labels(dir_img, dir_seg, n_classes, width, height ):
    images = os.listdir(dir_img)
    images.sort()
    segmentations  = os.listdir(dir_seg)
    segmentations.sort()
    X = [] # list of input images
    Y = [] # list of ground truth (gt)
    I = [] # List of image Filenames
    S = [] # List of gt filenames
    for im , seg in zip(images,segmentations) :
        img_filename = os.path.join(dir_img, im)
        seg_filename = os.path.join(dir_seg, seg)
        S.append(seg_filename)
        I.append(img_filename)
        X.append( NormalizeImageArr(img_filename)  )
        Y.append( LoadSegmentationArr( seg_filename, n_classes , width , height )  )
    X, Y = np.array(X) , np.array(Y)
    print("X tensor shape: ", X.shape, " Y tensor shape: ", Y.shape)
    return X, Y, I, S

def get_images(dir_img):
    images = os.listdir(dir_img)
    images.sort()
    X = []
    for im in images :
        img_filename = os.path.join(dir_img, im)
        X.append(NormalizeImageArr(img_filename)  )
    X = np.array(X)
    return X

#########################################################################################################
# Visualize the model performance

def visualize_model_performance(X_test, y_pred1_i, y_test1_i, n_classes):

    for k in range(5):

        i = k
        img_is  = (X_test[i] + 1)*(255.0/2)
        seg = y_pred1_i[i]
        segtest = y_test1_i[i]

        fig = plt.figure(figsize=(10,30))
        ax = fig.add_subplot(1,3,1)
        ax.imshow(img_is/255.0)
        ax.set_title("original")

        ax = fig.add_subplot(1,3,2)
        ax.imshow(give_color_to_seg_img(seg,n_classes))
        ax.set_title("predicted class")

        ax = fig.add_subplot(1,3,3)
        ax.imshow(give_color_to_seg_img(segtest,n_classes))
        ax.set_title("true class")

        

    plt.show()



print("\ncomputing IoU over testing data set:")
X_test =X_train
Y_test = Y_train
y_pred1   = model.predict(X_test, batch_size=2)
y_pred1_i = np.argmax(y_pred1, axis=3)
y_test1_i = np.argmax(Y_test, axis=3)
#print(y_test1_i.shape,y_pred1_i.shape)
IoU(y_test1_i, y_pred1_i)

print("\nnow computing IoU over validation data set:")
y_pred2 = model.predict(X_valid, batch_size=2)
y_pred2_i = np.argmax(y_pred2, axis=3)
y_test2_i = np.argmax(Y_valid, axis=3)
#print(y_test2_i.shape,y_pred2_i.shape)
IoU(y_test2_i,y_pred2_i)
visualize_model_performance(X_train, y_pred1_i, y_test1_i, N_CLASSES)
visualize_model_performance(X_valid, y_pred2_i, y_test2_i, N_CLASSES)
# Out:
# computing IoU over testing data set:
# class ( 0)         None: #TP=2208766, #FP= 120986, #FN=  44341, IoU=0.930
# class ( 1)          Sky: #TP=   1919, #FP=    459, #FN=  66666, IoU=0.028
# class ( 2)         Wall: #TP=      0, #FP=      0, #FN=   3147, IoU=0.000
# class ( 3)         Pole: #TP=      0, #FP=      0, #FN=  27531, IoU=0.000
# class ( 4)         Road: #TP= 480469, #FP=  67401, #FN=  47161, IoU=0.807
# _________________
# Mean IoU: 0.353
#
# now computing IoU over validation data set:
# class ( 0)         None: #TP= 839305, #FP=  69640, #FN=  39325, IoU=0.885
# class ( 1)          Sky: #TP=    522, #FP=    840, #FN=  26706, IoU=0.019
# class ( 2)         Wall: #TP=      0, #FP=      0, #FN=    500, IoU=0.000
# class ( 3)         Pole: #TP=      0, #FP=      0, #FN=   6027, IoU=0.000
# class ( 4)         Road: #TP= 192776, #FP=  48917, #FN=  46839, IoU=0.668
# _________________
# Mean IoU: 0.314

# %%
import tensorflow as tf
import sys, time, warnings
import keras as keras
from keras.models import *
from keras.layers import *
#from keras.utils import plot_model #DB
warnings.filterwarnings("ignore")


IMAGE_ORDERING =  "channels_last"



#Function to add 2 convolutional layers with the parameters passed to it
def conv2d_block(input_tensor, n_filters, kernel_size = 3, batchnorm = True, activation=True):
    #firt layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),
               kernel_initializer = 'he_normal', padding = 'same', data_format=IMAGE_ORDERING)(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    if activation:
        x = Activation('relu')(x)
    # second layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),
               kernel_initializer = 'he_normal', padding = 'same', data_format=IMAGE_ORDERING)(x)
    if batchnorm:
        x = BatchNormalization()(x)
    if activation:
        x = Activation('relu')(x)

    return x

# like UNET_v1 but with a Conv2D layer betweeb UpSampling2D aand Concatenate layers
def UNET_v2( nClasses, input_height, input_width, n_filters=16*2, dropout=0.1,
          batchnorm=True, activation=True):

    ## input_height and width must be devisible by 16 because maxpooling with filter size = (2,2) is operated 4 times,
    ## which makes the input_height and width 2^4 = 16 times smaller
    assert input_height%16 == 0
    assert input_width%16 == 0

    img_input = Input(shape=(input_height,input_width, 3)) ## Assume 224,224,3
    ## Downscaling

    ## Block 1: 64, 64
    c1 = conv2d_block(img_input, n_filters * 1, kernel_size = 3, batchnorm = batchnorm, activation=activation)
    c1 = conv2d_block(c1, n_filters * 1, kernel_size = 3, batchnorm = batchnorm, activation=activation)
    p1 = MaxPooling2D((2, 2))(c1)
    p1 = Dropout(dropout)(p1) # 112x112x64

    ## Block 2: 128, 128
    c2 = conv2d_block(p1, n_filters * 2, kernel_size = 3, batchnorm = batchnorm,  activation=activation)
    c2 = conv2d_block(c2, n_filters * 2, kernel_size = 3, batchnorm = batchnorm,  activation=activation)
    p2 = MaxPooling2D((2, 2))(c2)
    p2 = Dropout(dropout)(p2) # 56x56x128

    ## Block 3: 256, 256
    c3 = conv2d_block(p2, n_filters * 4, kernel_size = 3, batchnorm = batchnorm,  activation=activation)
    c3 = conv2d_block(c3, n_filters * 4, kernel_size = 3, batchnorm = batchnorm,  activation=activation)
    p3 = MaxPooling2D((2, 2))(c3)
    p3 = Dropout(dropout)(p3) # 28x28x256

    ## Block 4: 512, 512
    c4 = conv2d_block(p3, n_filters * 8, kernel_size = 3, batchnorm = batchnorm,  activation=activation)
    c4 = conv2d_block(c4, n_filters * 8, kernel_size = 3, batchnorm = batchnorm,  activation=activation)
    p4 = MaxPooling2D((2, 2))(c4)
    p4 = Dropout(dropout)(p4) # 14x14x512

    ## Block5: 1024, 1024
    c5 = conv2d_block(p4, n_filters = n_filters * 16, kernel_size = 3, batchnorm = batchnorm, activation=activation)
    c5 = conv2d_block(c5, n_filters = n_filters * 16, kernel_size = 3, batchnorm = batchnorm, activation=activation)
    p5 = Dropout(dropout)(c5) # 14x14x1024
    ## Upscaling

    ## Block6: 512, 512
    up6 = UpSampling2D(size=(2, 2),data_format=IMAGE_ORDERING, interpolation="bilinear")(p5) # 28x28x1024
    u6 = Conv2D(filters=n_filters*8, kernel_size=2, data_format=IMAGE_ORDERING,
                activation="relu", padding="same", kernel_initializer="he_normal")(up6)
    m6 = Concatenate(axis=3)([u6, c4])
    m6 = BatchNormalization()(m6)
    c6 = conv2d_block(m6, n_filters * 8, kernel_size = 3, batchnorm = batchnorm, activation=activation)
    
    ## Block7: 256, 256
    up7 = UpSampling2D(size=(2, 2),data_format=IMAGE_ORDERING, interpolation="bilinear")(c6) #56x56x256
    u7 = Conv2D(filters=n_filters*4, kernel_size=2, data_format=IMAGE_ORDERING,
                activation="relu", padding="same", kernel_initializer="he_normal")(up7)
    m7 = Concatenate(axis=3)([u7, c3])
    m7 = BatchNormalization()(m7)
    c7 = conv2d_block(m7, n_filters * 4, kernel_size = 3, batchnorm = batchnorm, activation=activation)
    
    ## Block8: 128, 128
    up8 = UpSampling2D(size=(2, 2),data_format=IMAGE_ORDERING, interpolation="bilinear")(c7) # 112x112x128
    u8  = Conv2D(filters=n_filters*2, kernel_size=2, data_format=IMAGE_ORDERING,
                activation="relu", padding="same", kernel_initializer="he_normal")(up8)
    m8  = Concatenate(axis=3)([u8, c2])
    m8 = BatchNormalization()(m8)
    c8 = conv2d_block(m8, n_filters * 2, kernel_size = 3, batchnorm = batchnorm, activation=activation)
    
    ## Block9: 64, 64
    up9 = UpSampling2D(size=(2, 2),data_format=IMAGE_ORDERING, interpolation="bilinear")(c8) # 224x224x64
    u9  = Conv2D(filters=n_filters*1, kernel_size=2, data_format=IMAGE_ORDERING,
                activation="relu", padding="same", kernel_initializer="he_normal")(up9)
    m9 = Concatenate(axis=3)([u9, c1])
    m9 = BatchNormalization()(m9)
    c9 = conv2d_block(m9, n_filters * 1, kernel_size = 3, batchnorm = batchnorm, activation=activation)
    
    ## Last layers
    c10 = Conv2D(filters=nClasses, kernel_size=1, data_format=IMAGE_ORDERING)(c9)
    o = (Activation("softmax"))(c10)
    model = Model(inputs=img_input, outputs=o)

    return model
