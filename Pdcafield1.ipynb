# %% [markdown]
# <a href="https://colab.research.google.com/github/madara-tribe/ML_algorithms/blob/master/Pdcafield4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt
#import seaborn as sns
from keras import optimizers
## Import usual libraries
import tensorflow as tf
import keras, sys, time, warnings
from keras.models import *
from keras.layers import *
from keras import optimizers
from keras import backend
from datetime import datetime #DB
import gc #DB
from tqdm import tqdm
from sklearn.utils import shuffle
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import LearningRateScheduler, ReduceLROnPlateau
warnings.filterwarnings("ignore")



import tensorflow as tf
import sys, time, warnings
import keras as keras
from keras.models import *
from keras.layers import *
#from keras.utils import plot_model #DB
warnings.filterwarnings("ignore")
IMAGE_ORDERING =  "channels_last"



#Function to add 2 convolutional layers with the parameters passed to it
def conv2d_block(input_tensor, n_filters, kernel_size = 3):
    #firt layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),
               kernel_initializer = 'he_normal', padding = 'same', data_format=IMAGE_ORDERING)(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    # second layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),
               kernel_initializer = 'he_normal', padding = 'same', data_format=IMAGE_ORDERING)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    return x
PLUS=30
# like UNET_v1 but with a Conv2D layer betweeb UpSampling2D aand Concatenate layers
def UNET_v2( nClasses, input_height, input_width, n_filters=16*2, dropout=0.1):

    ## input_height and width must be devisible by 16 because maxpooling with filter size = (2,2) is operated 4 times,
    ## which makes the input_height and width 2^4 = 16 times smaller
    assert input_height%16 == 0
    assert input_width%16 == 0

    img_input = Input(shape=(input_height,input_width, 3)) ## Assume 224,224,3
    ## Downscaling

    ## Block 1: 64, 64
    c1 = conv2d_block(img_input, n_filters * 1, kernel_size = 3)
    c1 = conv2d_block(c1, n_filters * 1, kernel_size = 3)
    p1 = MaxPooling2D((2, 2))(c1)
    p1 = Dropout(dropout)(p1) # 112x112x64

    ## Block 2: 128, 128
    c2 = conv2d_block(p1, n_filters * 2, kernel_size = 3)
    c2 = conv2d_block(c2, n_filters * 2, kernel_size = 3)
    p2 = MaxPooling2D((2, 2))(c2)
    p2 = Dropout(dropout)(p2) # 56x56x128

    ## Block 3: 256, 256
    c3 = conv2d_block(p2, n_filters * 4, kernel_size = 3)
    c3 = conv2d_block(c3, n_filters * 4, kernel_size = 3)
    p3 = MaxPooling2D((2, 2))(c3)
    p3 = Dropout(dropout)(p3) # 28x28x256

    ## Block 4: 512, 512
    c4 = conv2d_block(p3, n_filters * 8, kernel_size = 3)
    c4 = conv2d_block(c4, n_filters * 8, kernel_size = 3)
    p4 = MaxPooling2D((2, 2))(c4)
    p4 = Dropout(dropout)(p4) # 14x14x512

    ## Block5: 1024, 1024
    c5 = conv2d_block(p4, n_filters = (n_filters * 16)+PLUS, kernel_size = 3)
    c5 = conv2d_block(c5, n_filters = (n_filters * 16)+PLUS, kernel_size = 3)
    p5 = Dropout(dropout)(c5) # 14x14x1024
    ## Upscaling

    ## Block6: 512, 512
    up6 = UpSampling2D(size=(2, 2),data_format=IMAGE_ORDERING, interpolation="bilinear")(p5) # 28x28x1024
    u6 = Conv2D(filters=n_filters*8, kernel_size=2, data_format=IMAGE_ORDERING,
                activation=None, padding="same", kernel_initializer="he_normal")(up6)
    m6 = Concatenate(axis=3)([u6, c4])
    m6 = BatchNormalization()(m6)
    c6 = conv2d_block(m6, n_filters * 8, kernel_size = 3)
    
    ## Block7: 256, 256
    up7 = UpSampling2D(size=(2, 2),data_format=IMAGE_ORDERING, interpolation="bilinear")(c6) #56x56x256
    u7 = Conv2D(filters=n_filters*4, kernel_size=2, data_format=IMAGE_ORDERING,
                activation=None, padding="same", kernel_initializer="he_normal")(up7)
    m7 = Concatenate(axis=3)([u7, c3])
    m7 = BatchNormalization()(m7)
    c7 = conv2d_block(m7, n_filters * 4, kernel_size = 3)
    
    ## Block8: 128, 128
    up8 = UpSampling2D(size=(2, 2),data_format=IMAGE_ORDERING, interpolation="bilinear")(c7) # 112x112x128
    u8  = Conv2D(filters=n_filters*2, kernel_size=2, data_format=IMAGE_ORDERING,
                activation=None, padding="same", kernel_initializer="he_normal")(up8)
    m8  = Concatenate(axis=3)([u8, c2])
    m8 = BatchNormalization()(m8)
    c8 = conv2d_block(m8, n_filters * 2, kernel_size = 3)
    
    ## Block9: 64, 64
    up9 = UpSampling2D(size=(2, 2),data_format=IMAGE_ORDERING, interpolation="bilinear")(c8) # 224x224x64
    u9  = Conv2D(filters=n_filters*1, kernel_size=2, data_format=IMAGE_ORDERING,
                activation=None, padding="same", kernel_initializer="he_normal")(up9)
    m9 = Concatenate(axis=3)([u9, c1])
    m9 = BatchNormalization()(m9)
    c9 = conv2d_block(m9, n_filters * 1, kernel_size = 3)
    
    ## Last layers
    c10 = Conv2D(filters=nClasses, kernel_size=1, data_format=IMAGE_ORDERING)(c9)
    o = (Activation("softmax"))(c10)
    model = Model(inputs=img_input, outputs=o)

    return model


#Function to add 2 convolutional layers with the parameters passed to it
def conv2d_block(input_tensor, n_filters, kernel_size = 3):
    #firt layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),
               kernel_initializer = 'he_normal', padding = 'same')(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    # second layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),
               kernel_initializer = 'he_normal', padding = 'same')(x)
    x = BatchNormalization()(x)
    o = Activation('relu')(x)
    return o

PLUS=60
# like UNET_v1 but with a Conv2D layer betweeb UpSampling2D aand Concatenate layers
def UNET_v2( nClasses, input_height, input_width, n_filters=16*2, dropout=0.1):

    ## input_height and width must be devisible by 16 because maxpooling with filter size = (2,2) is operated 4 times,
    ## which makes the input_height and width 2^4 = 16 times smaller
    assert input_height%16 == 0
    assert input_width%16 == 0

    img_input = Input(shape=(input_height,input_width, 3)) ## Assume 224,224,3
    ## Downscaling

    ## Block 1: 64, 64
    c1 = conv2d_block(img_input, n_filters * 1, kernel_size = 3)
    c1 = conv2d_block(c1, n_filters * 1, kernel_size = 3)
    p1 = MaxPooling2D((2, 2))(c1)
    p1 = Dropout(dropout)(p1) # 112x112x64

    ## Block 2: 128, 128
    c2 = conv2d_block(p1, n_filters * 2, kernel_size = 3)
    c2 = conv2d_block(c2, n_filters * 2, kernel_size = 3)
    p2 = MaxPooling2D((2, 2))(c2)
    p2 = Dropout(dropout)(p2) # 56x56x128

    ## Block 3: 256, 256
    c3 = conv2d_block(p2, n_filters * 4, kernel_size = 3)
    c3 = conv2d_block(c3, n_filters * 4, kernel_size = 3)
    p3 = MaxPooling2D((2, 2))(c3)
    p3 = Dropout(dropout)(p3) # 28x28x256

    ## Block 4: 512, 512
    c4 = conv2d_block(p3, n_filters * 8, kernel_size = 3)
    c4 = conv2d_block(c4, n_filters * 8, kernel_size = 3)
    p4 = MaxPooling2D((2, 2))(c4)
    p4 = Dropout(dropout)(p4) # 14x14x512

    ## Block5: 1024, 1024
    c5 = conv2d_block(p4, n_filters = (n_filters * 16)+PLUS, kernel_size = 3)
    c5 = conv2d_block(c5, n_filters = (n_filters * 16)+PLUS, kernel_size = 3)
    p5 = Dropout(dropout)(c5) # 14x14x1024
    ## Upscaling

    ## Block6: 512, 512
    up6 = UpSampling2D(size=(2, 2), interpolation="bilinear")(p5) # 28x28x1024
    u6 = Conv2D(filters=n_filters*8, kernel_size=2, activation=None, padding="same", kernel_initializer="he_normal")(up6)
    m6 = Concatenate(axis=3)([u6, c4])
    m6 = BatchNormalization()(m6)
    c6 = conv2d_block(m6, n_filters * 8, kernel_size = 3)
    
    ## Block7: 256, 256
    up7 = UpSampling2D(size=(2, 2), interpolation="bilinear")(c6) #56x56x256
    u7 = Conv2D(filters=n_filters*4, kernel_size=2, activation=None, padding="same", kernel_initializer="he_normal")(up7)
    m7 = Concatenate(axis=3)([u7, c3])
    m7 = BatchNormalization()(m7)
    c7 = conv2d_block(m7, n_filters * 4, kernel_size = 3)
    
    ## Block8: 128, 128
    up8 = UpSampling2D(size=(2, 2), interpolation="bilinear")(c7) # 112x112x128
    u8  = Conv2D(filters=n_filters*2, kernel_size=2, activation=None, padding="same", kernel_initializer="he_normal")(up8)
    m8  = Concatenate(axis=3)([u8, c2])
    m8 = BatchNormalization()(m8)
    c8 = conv2d_block(m8, n_filters * 2, kernel_size = 3)
    
    ## Block9: 64, 64
    up9 = UpSampling2D(size=(2, 2), interpolation="bilinear")(c8) # 224x224x64
    u9  = Conv2D(filters=n_filters*1, kernel_size=2, activation=None, padding="same", kernel_initializer="he_normal")(up9)
    m9 = Concatenate(axis=3)([u9, c1])
    m9 = BatchNormalization()(m9)
    c9 = conv2d_block(m9, n_filters * 1, kernel_size = 3)
    
    ## Last layers
    c10 = Conv2D(filters=nClasses, kernel_size=1)(c9)
    o = (Activation("softmax"))(c10)
    model = Model(inputs=img_input, outputs=o)

    return model




N=160
HEIGHT = int(400-N)
WIDTH  = int(640-N)
print(HEIGHT, WIDTH)
N_CLASSES = 5

BATCH_SIZE = 2
EPOCHS = 100

weight_path='keras_model/fst.hdf5'
model_type = 2
model = UNET_v2(N_CLASSES, HEIGHT, WIDTH)
#model.load_weights(weight_path)
model.summary()
# Out:
# 240 480
# Model: "functional_11"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            [(None, 240, 480, 3) 0
# __________________________________________________________________________________________________
# conv2d_165 (Conv2D)             (None, 240, 480, 32) 896         input_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_160 (BatchN (None, 240, 480, 32) 128         conv2d_165[0][0]
# __________________________________________________________________________________________________
# activation_145 (Activation)     (None, 240, 480, 32) 0           batch_normalization_160[0][0]
# __________________________________________________________________________________________________
# conv2d_166 (Conv2D)             (None, 240, 480, 32) 9248        activation_145[0][0]
# __________________________________________________________________________________________________
# batch_normalization_161 (BatchN (None, 240, 480, 32) 128         conv2d_166[0][0]
# __________________________________________________________________________________________________
# activation_146 (Activation)     (None, 240, 480, 32) 0           batch_normalization_161[0][0]
# __________________________________________________________________________________________________
# conv2d_167 (Conv2D)             (None, 240, 480, 32) 9248        activation_146[0][0]
# __________________________________________________________________________________________________
# batch_normalization_162 (BatchN (None, 240, 480, 32) 128         conv2d_167[0][0]
# __________________________________________________________________________________________________
# activation_147 (Activation)     (None, 240, 480, 32) 0           batch_normalization_162[0][0]
# __________________________________________________________________________________________________
# conv2d_168 (Conv2D)             (None, 240, 480, 32) 9248        activation_147[0][0]
# __________________________________________________________________________________________________
# batch_normalization_163 (BatchN (None, 240, 480, 32) 128         conv2d_168[0][0]
# __________________________________________________________________________________________________
# activation_148 (Activation)     (None, 240, 480, 32) 0           batch_normalization_163[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_20 (MaxPooling2D) (None, 120, 240, 32) 0           activation_148[0][0]
# __________________________________________________________________________________________________
# dropout_25 (Dropout)            (None, 120, 240, 32) 0           max_pooling2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_169 (Conv2D)             (None, 120, 240, 64) 18496       dropout_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_164 (BatchN (None, 120, 240, 64) 256         conv2d_169[0][0]
# __________________________________________________________________________________________________
# activation_149 (Activation)     (None, 120, 240, 64) 0           batch_normalization_164[0][0]
# __________________________________________________________________________________________________
# conv2d_170 (Conv2D)             (None, 120, 240, 64) 36928       activation_149[0][0]
# __________________________________________________________________________________________________
# batch_normalization_165 (BatchN (None, 120, 240, 64) 256         conv2d_170[0][0]
# __________________________________________________________________________________________________
# activation_150 (Activation)     (None, 120, 240, 64) 0           batch_normalization_165[0][0]
# __________________________________________________________________________________________________
# conv2d_171 (Conv2D)             (None, 120, 240, 64) 36928       activation_150[0][0]
# __________________________________________________________________________________________________
# batch_normalization_166 (BatchN (None, 120, 240, 64) 256         conv2d_171[0][0]
# __________________________________________________________________________________________________
# activation_151 (Activation)     (None, 120, 240, 64) 0           batch_normalization_166[0][0]
# __________________________________________________________________________________________________
# conv2d_172 (Conv2D)             (None, 120, 240, 64) 36928       activation_151[0][0]
# __________________________________________________________________________________________________
# batch_normalization_167 (BatchN (None, 120, 240, 64) 256         conv2d_172[0][0]
# __________________________________________________________________________________________________
# activation_152 (Activation)     (None, 120, 240, 64) 0           batch_normalization_167[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_21 (MaxPooling2D) (None, 60, 120, 64)  0           activation_152[0][0]
# __________________________________________________________________________________________________
# dropout_26 (Dropout)            (None, 60, 120, 64)  0           max_pooling2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_173 (Conv2D)             (None, 60, 120, 128) 73856       dropout_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_168 (BatchN (None, 60, 120, 128) 512         conv2d_173[0][0]
# __________________________________________________________________________________________________
# activation_153 (Activation)     (None, 60, 120, 128) 0           batch_normalization_168[0][0]
# __________________________________________________________________________________________________
# conv2d_174 (Conv2D)             (None, 60, 120, 128) 147584      activation_153[0][0]
# __________________________________________________________________________________________________
# batch_normalization_169 (BatchN (None, 60, 120, 128) 512         conv2d_174[0][0]
# __________________________________________________________________________________________________
# activation_154 (Activation)     (None, 60, 120, 128) 0           batch_normalization_169[0][0]
# __________________________________________________________________________________________________
# conv2d_175 (Conv2D)             (None, 60, 120, 128) 147584      activation_154[0][0]
# __________________________________________________________________________________________________
# batch_normalization_170 (BatchN (None, 60, 120, 128) 512         conv2d_175[0][0]
# __________________________________________________________________________________________________
# activation_155 (Activation)     (None, 60, 120, 128) 0           batch_normalization_170[0][0]
# __________________________________________________________________________________________________
# conv2d_176 (Conv2D)             (None, 60, 120, 128) 147584      activation_155[0][0]
# __________________________________________________________________________________________________
# batch_normalization_171 (BatchN (None, 60, 120, 128) 512         conv2d_176[0][0]
# __________________________________________________________________________________________________
# activation_156 (Activation)     (None, 60, 120, 128) 0           batch_normalization_171[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_22 (MaxPooling2D) (None, 30, 60, 128)  0           activation_156[0][0]
# __________________________________________________________________________________________________
# dropout_27 (Dropout)            (None, 30, 60, 128)  0           max_pooling2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_177 (Conv2D)             (None, 30, 60, 256)  295168      dropout_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_172 (BatchN (None, 30, 60, 256)  1024        conv2d_177[0][0]
# __________________________________________________________________________________________________
# activation_157 (Activation)     (None, 30, 60, 256)  0           batch_normalization_172[0][0]
# __________________________________________________________________________________________________
# conv2d_178 (Conv2D)             (None, 30, 60, 256)  590080      activation_157[0][0]
# __________________________________________________________________________________________________
# batch_normalization_173 (BatchN (None, 30, 60, 256)  1024        conv2d_178[0][0]
# __________________________________________________________________________________________________
# activation_158 (Activation)     (None, 30, 60, 256)  0           batch_normalization_173[0][0]
# __________________________________________________________________________________________________
# conv2d_179 (Conv2D)             (None, 30, 60, 256)  590080      activation_158[0][0]
# __________________________________________________________________________________________________
# batch_normalization_174 (BatchN (None, 30, 60, 256)  1024        conv2d_179[0][0]
# __________________________________________________________________________________________________
# activation_159 (Activation)     (None, 30, 60, 256)  0           batch_normalization_174[0][0]
# __________________________________________________________________________________________________
# conv2d_180 (Conv2D)             (None, 30, 60, 256)  590080      activation_159[0][0]
# __________________________________________________________________________________________________
# batch_normalization_175 (BatchN (None, 30, 60, 256)  1024        conv2d_180[0][0]
# __________________________________________________________________________________________________
# activation_160 (Activation)     (None, 30, 60, 256)  0           batch_normalization_175[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_23 (MaxPooling2D) (None, 15, 30, 256)  0           activation_160[0][0]
# __________________________________________________________________________________________________
# dropout_28 (Dropout)            (None, 15, 30, 256)  0           max_pooling2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_181 (Conv2D)             (None, 15, 30, 572)  1318460     dropout_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_176 (BatchN (None, 15, 30, 572)  2288        conv2d_181[0][0]
# __________________________________________________________________________________________________
# activation_161 (Activation)     (None, 15, 30, 572)  0           batch_normalization_176[0][0]
# __________________________________________________________________________________________________
# conv2d_182 (Conv2D)             (None, 15, 30, 572)  2945228     activation_161[0][0]
# __________________________________________________________________________________________________
# batch_normalization_177 (BatchN (None, 15, 30, 572)  2288        conv2d_182[0][0]
# __________________________________________________________________________________________________
# activation_162 (Activation)     (None, 15, 30, 572)  0           batch_normalization_177[0][0]
# __________________________________________________________________________________________________
# conv2d_183 (Conv2D)             (None, 15, 30, 572)  2945228     activation_162[0][0]
# __________________________________________________________________________________________________
# batch_normalization_178 (BatchN (None, 15, 30, 572)  2288        conv2d_183[0][0]
# __________________________________________________________________________________________________
# activation_163 (Activation)     (None, 15, 30, 572)  0           batch_normalization_178[0][0]
# __________________________________________________________________________________________________
# conv2d_184 (Conv2D)             (None, 15, 30, 572)  2945228     activation_163[0][0]
# __________________________________________________________________________________________________
# batch_normalization_179 (BatchN (None, 15, 30, 572)  2288        conv2d_184[0][0]
# __________________________________________________________________________________________________
# activation_164 (Activation)     (None, 15, 30, 572)  0           batch_normalization_179[0][0]
# __________________________________________________________________________________________________
# dropout_29 (Dropout)            (None, 15, 30, 572)  0           activation_164[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_20 (UpSampling2D) (None, 30, 60, 572)  0           dropout_29[0][0]
# __________________________________________________________________________________________________
# conv2d_185 (Conv2D)             (None, 30, 60, 256)  585984      up_sampling2d_20[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 30, 60, 512)  0           conv2d_185[0][0]
#                                                                  activation_160[0][0]
# __________________________________________________________________________________________________
# batch_normalization_180 (BatchN (None, 30, 60, 512)  2048        concatenate_20[0][0]
# __________________________________________________________________________________________________
# conv2d_186 (Conv2D)             (None, 30, 60, 256)  1179904     batch_normalization_180[0][0]
# __________________________________________________________________________________________________
# batch_normalization_181 (BatchN (None, 30, 60, 256)  1024        conv2d_186[0][0]
# __________________________________________________________________________________________________
# activation_165 (Activation)     (None, 30, 60, 256)  0           batch_normalization_181[0][0]
# __________________________________________________________________________________________________
# conv2d_187 (Conv2D)             (None, 30, 60, 256)  590080      activation_165[0][0]
# __________________________________________________________________________________________________
# batch_normalization_182 (BatchN (None, 30, 60, 256)  1024        conv2d_187[0][0]
# __________________________________________________________________________________________________
# activation_166 (Activation)     (None, 30, 60, 256)  0           batch_normalization_182[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_21 (UpSampling2D) (None, 60, 120, 256) 0           activation_166[0][0]
# __________________________________________________________________________________________________
# conv2d_188 (Conv2D)             (None, 60, 120, 128) 131200      up_sampling2d_21[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 60, 120, 256) 0           conv2d_188[0][0]
#                                                                  activation_156[0][0]
# __________________________________________________________________________________________________
# batch_normalization_183 (BatchN (None, 60, 120, 256) 1024        concatenate_21[0][0]
# __________________________________________________________________________________________________
# conv2d_189 (Conv2D)             (None, 60, 120, 128) 295040      batch_normalization_183[0][0]
# __________________________________________________________________________________________________
# batch_normalization_184 (BatchN (None, 60, 120, 128) 512         conv2d_189[0][0]
# __________________________________________________________________________________________________
# activation_167 (Activation)     (None, 60, 120, 128) 0           batch_normalization_184[0][0]
# __________________________________________________________________________________________________
# conv2d_190 (Conv2D)             (None, 60, 120, 128) 147584      activation_167[0][0]
# __________________________________________________________________________________________________
# batch_normalization_185 (BatchN (None, 60, 120, 128) 512         conv2d_190[0][0]
# __________________________________________________________________________________________________
# activation_168 (Activation)     (None, 60, 120, 128) 0           batch_normalization_185[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_22 (UpSampling2D) (None, 120, 240, 128 0           activation_168[0][0]
# __________________________________________________________________________________________________
# conv2d_191 (Conv2D)             (None, 120, 240, 64) 32832       up_sampling2d_22[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 120, 240, 128 0           conv2d_191[0][0]
#                                                                  activation_152[0][0]
# __________________________________________________________________________________________________
# batch_normalization_186 (BatchN (None, 120, 240, 128 512         concatenate_22[0][0]
# __________________________________________________________________________________________________
# conv2d_192 (Conv2D)             (None, 120, 240, 64) 73792       batch_normalization_186[0][0]
# __________________________________________________________________________________________________
# batch_normalization_187 (BatchN (None, 120, 240, 64) 256         conv2d_192[0][0]
# __________________________________________________________________________________________________
# activation_169 (Activation)     (None, 120, 240, 64) 0           batch_normalization_187[0][0]
# __________________________________________________________________________________________________
# conv2d_193 (Conv2D)             (None, 120, 240, 64) 36928       activation_169[0][0]
# __________________________________________________________________________________________________
# batch_normalization_188 (BatchN (None, 120, 240, 64) 256         conv2d_193[0][0]
# __________________________________________________________________________________________________
# activation_170 (Activation)     (None, 120, 240, 64) 0           batch_normalization_188[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_23 (UpSampling2D) (None, 240, 480, 64) 0           activation_170[0][0]
# __________________________________________________________________________________________________
# conv2d_194 (Conv2D)             (None, 240, 480, 32) 8224        up_sampling2d_23[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 240, 480, 64) 0           conv2d_194[0][0]
#                                                                  activation_148[0][0]
# __________________________________________________________________________________________________
# batch_normalization_189 (BatchN (None, 240, 480, 64) 256         concatenate_23[0][0]
# __________________________________________________________________________________________________
# conv2d_195 (Conv2D)             (None, 240, 480, 32) 18464       batch_normalization_189[0][0]
# __________________________________________________________________________________________________
# batch_normalization_190 (BatchN (None, 240, 480, 32) 128         conv2d_195[0][0]
# __________________________________________________________________________________________________
# activation_171 (Activation)     (None, 240, 480, 32) 0           batch_normalization_190[0][0]
# __________________________________________________________________________________________________
# conv2d_196 (Conv2D)             (None, 240, 480, 32) 9248        activation_171[0][0]
# __________________________________________________________________________________________________
# batch_normalization_191 (BatchN (None, 240, 480, 32) 128         conv2d_196[0][0]
# __________________________________________________________________________________________________
# activation_172 (Activation)     (None, 240, 480, 32) 0           batch_normalization_191[0][0]
# __________________________________________________________________________________________________
# conv2d_197 (Conv2D)             (None, 240, 480, 5)  165         activation_172[0][0]
# __________________________________________________________________________________________________
# activation_173 (Activation)     (None, 240, 480, 5)  0           conv2d_197[0][0]
# ==================================================================================================
# Total params: 16,028,037
# Trainable params: 16,015,781
# Non-trainable params: 12,256
# __________________________________________________________________________________________________

# %%
path='/content/drive/MyDrive/4cls/'
dir_train_img=path+'train'
dir_train_seg=path+'anno'
dir_valid_img = path+'val'
dir_valid_seg = path+'val_anno'

def noise_chale(bgr):
    ksize = 3
    #plt.imshow(bgr),plt.show()
    lab = cv2.cvtColor(bgr, cv2.COLOR_BGR2LAB)
    #plt.imshow(lab),plt.show()
    lab_planes = cv2.split(lab)
    lab_planes[0] = cv2.medianBlur(lab_planes[0], ksize)
    lab = cv2.merge(lab_planes)
    return cv2.cvtColor(lab, cv2.COLOR_LAB2BGR)
	


def flipud_image(X, Y):
    Xflip =np.array([img[::-1] for img in X])
    Yflip =np.array([img[::-1] for img in Y])
    return Xflip, Yflip
    
def fliplr_image(X, Y):
    Xflip =np.array([img[:, ::-1] for img in X])
    Yflip =np.array([img[:, ::-1] for img in Y])
    return Xflip, Yflip

def salt(img):
    row,col,ch = img.shape
    s_vs_p = 0.5
    amount = 0.004
    sp_img = img.copy()
    # pepper
    num_pepper = np.ceil(amount* img.size * (1. - s_vs_p))
    coords = [np.random.randint(0, i-1 , int(num_pepper)) for i in img.shape]
    sp_img[coords[:-1]] = (0,0,0)
    return sp_img
	
	
def channel_shift(img, value):
    value = int(random.uniform(-value, value))
    img = img + value
    img[:,:,:][img[:,:,:]>255]  = 255
    img[:,:,:][img[:,:,:]<0]  = 0
    #img = img.astype(np.uint8)
    return img

def contrast(img, gamma = 0.5):
    gamma_cvt = np.zeros((256,1),dtype = 'uint8')
 
    for i in range(256):
        gamma_cvt[i][0] = 255 * (float(i)/255) ** (1.0/gamma)
    return cv2.LUT(img, gamma_cvt)

def sift_angle(image, y_move_ratio=0, x_move_ratio=0, angle_ratio=float(np.pi/60)):
    h, w, _ = np.shape(image)
    size = tuple(np.array([w, h]))
    print(size)
    #np.pi=3.141592653589793
    rad=angle_ratio
    move_x = x_move_ratio
    move_y = w * y_move_ratio

    matrix = [[np.cos(rad), -1 * np.sin(rad), move_x],
                   [np.sin(rad), np.cos(rad), move_y]]

    affine_matrix = np.float32(matrix)
    chage_angle = cv2.warpAffine(image, affine_matrix, size, flags=cv2.INTER_LINEAR)
    return chage_angle

def clahe(bgr):
    #plt.imshow(bgr),plt.show()
    lab = cv2.cvtColor(bgr, cv2.COLOR_BGR2LAB)
    #plt.imshow(lab),plt.show()
    lab_planes = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=10.0,tileGridSize=(8,8))
    lab_planes[0] = clahe.apply(lab_planes[0])
    lab = cv2.merge(lab_planes)
    return cv2.cvtColor(lab, cv2.COLOR_LAB2BGR)


def ContrastNormalizeImageArr(path, H, W, gamma=1.8):
    NORM_FACTOR = 255
    img = cv2.imread(path, 1)
    img = contrast(img, gamma = gamma)
    img = cv2.resize(img, (H, W), interpolation=cv2.INTER_NEAREST)
    img = img.astype(np.float32)
    img = img/NORM_FACTOR
    return img
def noise(img):
	ksize = 3
	for j in range(3):
		img[:,:,j]=cv2.medianBlur(img[:, :, j], ksize)
	return img


def NormalizeImageArr(path, H, W, aug_type=None):
    aug_type = aug_type
    NORM_FACTOR = 255
    img = cv2.imread(path, 1)
    img = cv2.resize(img, (H, W), interpolation=cv2.INTER_NEAREST)
    if img.mean()<80:
        img = clahe(img)
    else: 
        img = noise_chale(img)
    
    if aug_type == 'pepper':
        img = salt(img)
    elif aug_type == 'sift':
        img = channel_shift(img, 60)
    else:
        pass
    img = img.astype(np.float32)
    img = img/NORM_FACTOR
    return img

def LoadSegmentationArr( path , nClasses,  width ,height):
    seg_labels = np.zeros((height, width, nClasses))
    img = cv2.imread(path, 1)
    img = cv2.resize(img, (width, height), interpolation=cv2.INTER_NEAREST)
    img = img[:, : , 0]
    for c in range(nClasses):
        seg_labels[: , : , c ] = (img == c ).astype(int)
    return seg_labels

print('train load')
train_images = os.listdir(dir_train_img)
train_images.sort()
train_segmentations  = os.listdir(dir_train_seg)
train_segmentations.sort()
X_train, Y_train=[], []

for im , seg in tqdm(zip(train_images[:25], train_segmentations[:25])):
    X_train.append(NormalizeImageArr(os.path.join(dir_train_img,im), WIDTH, HEIGHT, aug_type=None))
    Y_train.append(LoadSegmentationArr( os.path.join(dir_train_seg,seg), N_CLASSES, WIDTH, HEIGHT)  )

X_train, Y_train = np.array(X_train), np.array(Y_train)
#X1, Y1 = fliplr_image(X_train, Y_train)
#X_train = np.vstack([X_train, X1])

#X_train, Y_train = shuffle(X_train, Y_train)
print(X_train.shape,Y_train.shape)
print(X_train.max(), X_train.min())

# In[13]:


# load validation images
valid_images = os.listdir(dir_valid_img)
valid_images.sort()
valid_segmentations  = os.listdir(dir_valid_seg)
valid_segmentations.sort()
X_valid, Y_valid = [], []

for im , seg in tqdm(zip(valid_images,valid_segmentations)):
    X_valid.append(NormalizeImageArr(os.path.join(dir_valid_img,im), WIDTH, HEIGHT) )
    Y_valid.append(LoadSegmentationArr( os.path.join(dir_valid_seg,seg) , N_CLASSES, WIDTH, HEIGHT))


X_valid, Y_valid = np.array(X_valid), np.array(Y_valid)
#Xv1, Yv1 = fliplr_image(X_valid, Y_valid)
#X_valid = np.vstack([X_valid, Xv1])
#Y_valid = np.vstack([Y_valid, Yv1])
print(X_valid.shape,Y_valid.shape)
print(X_valid.max(),X_valid.min())
plt.imshow(X_train[5]),plt.show()
plt.imshow(X_valid[2]),plt.show()
# Out:
# 2it [00:00, 14.01it/s]
# train load
# 25it [00:01, 14.24it/s]
# 2it [00:00, 14.56it/s]
# (25, 240, 480, 3) (25, 240, 480, 5)
# 1.0 0.0
# 10it [00:00, 13.77it/s]
# (10, 240, 480, 3) (10, 240, 480, 5)
# 1.0 0.0
# (<matplotlib.image.AxesImage at 0x7f65b23c00b8>, None)

# %%
checkpoint_path = "train_ck/cp-{epoch:04d}.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
 
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    checkpoint_path, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True, period=1)


reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, verbose=1)
callback = [reduce_lr]

adam=optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0)
model.compile(loss='categorical_crossentropy',
              optimizer=adam,
              metrics=['accuracy'])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
startTime1 = datetime.now() #DB
hist1 = model.fit(X_train,Y_train, validation_data=(X_valid,Y_valid), 
                  batch_size=2,epochs=100)
endTime1 = datetime.now()
diff1 = endTime1 - startTime1
print("\n")
print("Elapsed time for Keras training (s): ", diff1.total_seconds())
print("\n")

for key in ["loss", "val_loss"]:
    plt.plot(hist1.history[key],label=key)
plt.legend()

print("\nEnd of UNET training\n")
# Out:
# Epoch 1/100
# 13/13 [==============================] - ETA: 0s - loss: 0.0728 - accuracy: 0.9739WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0064s vs `on_test_batch_end` time: 0.0393s). Check your callbacks.
# 13/13 [==============================] - 2s 182ms/step - loss: 0.0728 - accuracy: 0.9739 - val_loss: 0.3373 - val_accuracy: 0.9140
# Epoch 2/100
# 13/13 [==============================] - 2s 176ms/step - loss: 0.0668 - accuracy: 0.9759 - val_loss: 0.3151 - val_accuracy: 0.9109
# Epoch 3/100
# 13/13 [==============================] - 2s 176ms/step - loss: 0.0600 - accuracy: 0.9782 - val_loss: 0.3140 - val_accuracy: 0.9025
# Epoch 4/100
# 13/13 [==============================] - 2s 176ms/step - loss: 0.0577 - accuracy: 0.9797 - val_loss: 0.3266 - val_accuracy: 0.9118
# Epoch 5/100
# 13/13 [==============================] - 2s 177ms/step - loss: 0.0568 - accuracy: 0.9801 - val_loss: 0.3231 - val_accuracy: 0.9142
# Epoch 6/100
# 13/13 [==============================] - 2s 177ms/step - loss: 0.0510 - accuracy: 0.9820 - val_loss: 0.3175 - val_accuracy: 0.9172
# Epoch 7/100
# 13/13 [==============================] - 2s 177ms/step - loss: 0.0507 - accuracy: 0.9818 - val_loss: 0.3116 - val_accuracy: 0.9142
# Epoch 8/100
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0493 - accuracy: 0.9826 - val_loss: 0.3022 - val_accuracy: 0.9105
# Epoch 9/100
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0483 - accuracy: 0.9824 - val_loss: 0.2914 - val_accuracy: 0.9255
# Epoch 10/100
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0474 - accuracy: 0.9829 - val_loss: 0.3079 - val_accuracy: 0.9217
# Epoch 11/100
# 13/13 [==============================] - 2s 179ms/step - loss: 0.0463 - accuracy: 0.9832 - val_loss: 0.2968 - val_accuracy: 0.9245
# Epoch 12/100
# 13/13 [==============================] - 2s 179ms/step - loss: 0.0446 - accuracy: 0.9840 - val_loss: 0.3131 - val_accuracy: 0.9217
# Epoch 13/100
# 13/13 [==============================] - 2s 179ms/step - loss: 0.0463 - accuracy: 0.9832 - val_loss: 0.3154 - val_accuracy: 0.9157
# Epoch 14/100
# 13/13 [==============================] - 2s 179ms/step - loss: 0.0854 - accuracy: 0.9705 - val_loss: 0.5477 - val_accuracy: 0.8369
# Epoch 15/100
# 13/13 [==============================] - 2s 179ms/step - loss: 0.0849 - accuracy: 0.9689 - val_loss: 0.4148 - val_accuracy: 0.8908
# Epoch 16/100
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0779 - accuracy: 0.9717 - val_loss: 0.7128 - val_accuracy: 0.8225
# Epoch 17/100
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0689 - accuracy: 0.9749 - val_loss: 0.4486 - val_accuracy: 0.8863
# Epoch 18/100
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0557 - accuracy: 0.9799 - val_loss: 0.5005 - val_accuracy: 0.8630
# Epoch 19/100
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0516 - accuracy: 0.9814 - val_loss: 0.3846 - val_accuracy: 0.9051
# Epoch 20/100
# 13/13 [==============================] - 2s 177ms/step - loss: 0.0500 - accuracy: 0.9817 - val_loss: 0.4084 - val_accuracy: 0.9006
# Epoch 21/100
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0490 - accuracy: 0.9822 - val_loss: 0.3125 - val_accuracy: 0.9173
# Epoch 22/100
# 13/13 [==============================] - 2s 177ms/step - loss: 0.0490 - accuracy: 0.9822 - val_loss: 0.4165 - val_accuracy: 0.9038
# Epoch 23/100
# 13/13 [==============================] - 2s 177ms/step - loss: 0.0500 - accuracy: 0.9816 - val_loss: 0.4183 - val_accuracy: 0.8990
# Epoch 24/100
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0504 - accuracy: 0.9813 - val_loss: 0.3778 - val_accuracy: 0.9040
# Epoch 25/100
# 13/13 [==============================] - 2s 177ms/step - loss: 0.0486 - accuracy: 0.9824 - val_loss: 0.3435 - val_accuracy: 0.9162
# Epoch 26/100
# 13/13 [==============================] - 2s 177ms/step - loss: 0.0520 - accuracy: 0.9805 - val_loss: 0.3533 - val_accuracy: 0.9143
# Epoch 27/100
# 13/13 [==============================] - 2s 177ms/step - loss: 0.
100
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0250 - accuracy: 0.9904 - val_loss: 0.3418 - val_accuracy: 0.9280
# Epoch 91/100
# 13/13 [==============================] - 2s 177ms/step - loss: 0.0326 - accuracy: 0.9876 - val_loss: 0.3467 - val_accuracy: 0.9209
# Epoch 92/100
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0364 - accuracy: 0.9863 - val_loss: 0.4450 - val_accuracy: 0.9102
# Epoch 93/100
# 13/13 [==============================] - 2s 177ms/step - loss: 0.0425 - accuracy: 0.9843 - val_loss: 0.4455 - val_accuracy: 0.9074
# Epoch 94/100
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0418 - accuracy: 0.9840 - val_loss: 0.4049 - val_accuracy: 0.9119
# Epoch 95/100
# 13/13 [==============================] - 2s 177ms/step - loss: 0.0373 - accuracy: 0.9857 - val_loss: 0.4482 - val_accuracy: 0.9001
# Epoch 96/100
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0312 - accuracy: 0.9881 - val_loss: 0.3557 - val_accuracy: 0.9190
# Epoch 97/100
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0281 - accuracy: 0.9895 - val_loss: 0.3441 - val_accuracy: 0.9262
# Epoch 98/100
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0258 - accuracy: 0.9902 - val_loss: 0.3531 - val_accuracy: 0.9254
# Epoch 99/100
# 13/13 [==============================] - 2s 177ms/step - loss: 0.0259 - accuracy: 0.9902 - val_loss: 0.3582 - val_accuracy: 0.9244
# Epoch 100/100
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0247 - accuracy: 0.9905 - val_loss: 0.3484 - val_accuracy: 0.9242
#
#
# Elapsed time for Keras training (s):  237.786234
#
#
#
# End of UNET training

# %%
# names of classes
CLASS_NAMES = ("None", "Sky",
               "Wall",
               "Pole",
               "Road",
               "Sidewalk",
               "Vegetation",
               "Sign",
               "Fence",
               "vehicle",
               "Pedestrian")


EPOCHS = 200


#######################################################################################################

# colors for segmented classes
colorB = [128, 232, 70, 156, 153, 153,  30,   0,  35, 152, 180,  60,   0, 142, 70, 100, 100, 230,  32]
colorG = [ 64,  35, 70, 102, 153, 153, 170, 220, 142, 251, 130,  20,   0,   0,  0,  60,  80,   0,  11]
colorR = [128, 244, 70, 102, 190, 153, 250, 220, 107, 152,  70, 220, 255,   0,  0,   0,   0,   0, 119]
CLASS_COLOR = list()
for i in range(0, 19):
    CLASS_COLOR.append([colorR[i], colorG[i], colorB[i]])
COLORS = np.array(CLASS_COLOR, dtype="float32")


def give_color_to_seg_img(seg,n_classes):
    if len(seg.shape)==3:
        seg = seg[:,:,0]
    seg_img = np.zeros( (seg.shape[0],seg.shape[1],3) ).astype('float')
    #colors = sns.color_palette("hls", n_classes) #DB
    colors = COLORS #DB
    for c in range(n_classes):
        segc = (seg == c)
        seg_img[:,:,0] += (segc*( colors[c][0]/255.0 ))
        seg_img[:,:,1] += (segc*( colors[c][1]/255.0 ))
        seg_img[:,:,2] += (segc*( colors[c][2]/255.0 ))

    return(seg_img)

def IoU(Yi,y_predi):
    ## mean Intersection over Union
    ## Mean IoU = TP/(FN + TP + FP)
    IoUs = []
    Nclass = int(np.max(Yi)) + 1
    for c in range(Nclass):
        TP = np.sum( (Yi == c)&(y_predi == c))
        FP = np.sum( (Yi != c)&(y_predi == c))
        FN = np.sum( (Yi == c)&(y_predi != c))
        IoU = TP/float(TP + FP + FN)
        #print("class {:02.0f}: #TP={:7.0f}, #FP={:7.0f}, #FN={:7.0f}, IoU={:4.3f}".format(c,TP,FP,FN,IoU))
        print("class (%2d) %12.12s: #TP=%7.0f, #FP=%7.0f, #FN=%7.0f, IoU=%4.3f" % (c, CLASS_NAMES[c],TP,FP,FN,IoU))
        IoUs.append(IoU)
    mIoU = np.mean(IoUs)
    print("_________________")
    print("Mean IoU: {:4.3f}".format(mIoU))
    return


def get_images_and_labels(dir_img, dir_seg, n_classes, width, height ):
    images = os.listdir(dir_img)
    images.sort()
    segmentations  = os.listdir(dir_seg)
    segmentations.sort()
    X = [] # list of input images
    Y = [] # list of ground truth (gt)
    I = [] # List of image Filenames
    S = [] # List of gt filenames
    for im , seg in zip(images,segmentations) :
        img_filename = os.path.join(dir_img, im)
        seg_filename = os.path.join(dir_seg, seg)
        S.append(seg_filename)
        I.append(img_filename)
        X.append( NormalizeImageArr(img_filename)  )
        Y.append( LoadSegmentationArr( seg_filename, n_classes , width , height )  )
    X, Y = np.array(X) , np.array(Y)
    print("X tensor shape: ", X.shape, " Y tensor shape: ", Y.shape)
    return X, Y, I, S

def get_images(dir_img):
    images = os.listdir(dir_img)
    images.sort()
    X = []
    for im in images :
        img_filename = os.path.join(dir_img, im)
        X.append(NormalizeImageArr(img_filename)  )
    X = np.array(X)
    return X

#########################################################################################################
# Visualize the model performance

def visualize_model_performance(X_test, y_pred1_i, y_test1_i, n_classes):

    for k in range(5):

        i = k
        img_is  = (X_test[i] + 1)*(255.0/2)
        seg = y_pred1_i[i]
        segtest = y_test1_i[i]

        fig = plt.figure(figsize=(10,30))
        ax = fig.add_subplot(1,3,1)
        ax.imshow(img_is/255.0)
        ax.set_title("original")

        ax = fig.add_subplot(1,3,2)
        ax.imshow(give_color_to_seg_img(seg,n_classes))
        ax.set_title("predicted class")

        ax = fig.add_subplot(1,3,3)
        ax.imshow(give_color_to_seg_img(segtest,n_classes))
        ax.set_title("true class")

        

    plt.show()

# %%
print("\ncomputing IoU over testing data set:")
X_test =X_train
Y_test = Y_train
y_pred1   = model.predict(X_test, batch_size=2)
y_pred1_i = np.argmax(y_pred1, axis=3)
y_test1_i = np.argmax(Y_test, axis=3)
#print(y_test1_i.shape,y_pred1_i.shape)
IoU(y_test1_i, y_pred1_i)

print("\nnow computing IoU over validation data set:")
y_pred2 = model.predict(X_valid, batch_size=2)
y_pred2_i = np.argmax(y_pred2, axis=3)
y_test2_i = np.argmax(Y_valid, axis=3)
#print(y_test2_i.shape,y_pred2_i.shape)
IoU(y_test2_i,y_pred2_i)
visualize_model_performance(X_valid, y_pred2_i, y_test2_i,N_CLASSES)
visualize_model_performance(X_train, y_pred1_i, y_test1_i, N_CLASSES)
# Out:
# computing IoU over testing data set:
# class ( 0)         None: #TP=2239784, #FP=  11429, #FN=  13323, IoU=0.989
# class ( 1)          Sky: #TP=  65687, #FP=  10132, #FN=   2898, IoU=0.834
# class ( 2)         Wall: #TP=   2567, #FP=    723, #FN=    580, IoU=0.663
# class ( 3)         Pole: #TP=  24651, #FP=   3857, #FN=   2880, IoU=0.785
# class ( 4)         Road: #TP= 512170, #FP=   9000, #FN=  15460, IoU=0.954
# _________________
# Mean IoU: 0.845
#
# now computing IoU over validation data set:
# class ( 0)         None: #TP= 840139, #FP=  43794, #FN=  38491, IoU=0.911
# class ( 1)          Sky: #TP=   8345, #FP=   3238, #FN=  18883, IoU=0.274
# class ( 2)         Wall: #TP=     21, #FP=    236, #FN=    479, IoU=0.029
# class ( 3)         Pole: #TP=   1972, #FP=   6259, #FN=   4055, IoU=0.161
# class ( 4)         Road: #TP= 214156, #FP=  33840, #FN=  25459, IoU=0.783
# _________________
# Mean IoU: 0.431

# %%
import tensorflow as tf
import sys, time, warnings
import keras as keras
from keras.models import *
from keras.layers import *
#from keras.utils import plot_model #DB
warnings.filterwarnings("ignore")


IMAGE_ORDERING =  "channels_last"



#Function to add 2 convolutional layers with the parameters passed to it
def conv2d_block(input_tensor, n_filters, kernel_size = 3, batchnorm = True, activation=True):
    #firt layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),
               kernel_initializer = 'he_normal', padding = 'same', data_format=IMAGE_ORDERING)(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    if activation:
        x = Activation('relu')(x)
    # second layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),
               kernel_initializer = 'he_normal', padding = 'same', data_format=IMAGE_ORDERING)(x)
    if batchnorm:
        x = BatchNormalization()(x)
    if activation:
        x = Activation('relu')(x)

    return x

# like UNET_v1 but with a Conv2D layer betweeb UpSampling2D aand Concatenate layers
def UNET_v2( nClasses, input_height, input_width, n_filters=16*2, dropout=0.1,
          batchnorm=True, activation=True):

    ## input_height and width must be devisible by 16 because maxpooling with filter size = (2,2) is operated 4 times,
    ## which makes the input_height and width 2^4 = 16 times smaller
    assert input_height%16 == 0
    assert input_width%16 == 0

    img_input = Input(shape=(input_height,input_width, 3)) ## Assume 224,224,3
    ## Downscaling

    ## Block 1: 64, 64
    c1 = conv2d_block(img_input, n_filters * 1, kernel_size = 3, batchnorm = batchnorm, activation=activation)
    c1 = conv2d_block(c1, n_filters * 1, kernel_size = 3, batchnorm = batchnorm, activation=activation)
    p1 = MaxPooling2D((2, 2))(c1)
    p1 = Dropout(dropout)(p1) # 112x112x64

    ## Block 2: 128, 128
    c2 = conv2d_block(p1, n_filters * 2, kernel_size = 3, batchnorm = batchnorm,  activation=activation)
    c2 = conv2d_block(c2, n_filters * 2, kernel_size = 3, batchnorm = batchnorm,  activation=activation)
    p2 = MaxPooling2D((2, 2))(c2)
    p2 = Dropout(dropout)(p2) # 56x56x128

    ## Block 3: 256, 256
    c3 = conv2d_block(p2, n_filters * 4, kernel_size = 3, batchnorm = batchnorm,  activation=activation)
    c3 = conv2d_block(c3, n_filters * 4, kernel_size = 3, batchnorm = batchnorm,  activation=activation)
    p3 = MaxPooling2D((2, 2))(c3)
    p3 = Dropout(dropout)(p3) # 28x28x256

    ## Block 4: 512, 512
    c4 = conv2d_block(p3, n_filters * 8, kernel_size = 3, batchnorm = batchnorm,  activation=activation)
    c4 = conv2d_block(c4, n_filters * 8, kernel_size = 3, batchnorm = batchnorm,  activation=activation)
    p4 = MaxPooling2D((2, 2))(c4)
    p4 = Dropout(dropout)(p4) # 14x14x512

    ## Block5: 1024, 1024
    c5 = conv2d_block(p4, n_filters = n_filters * 16, kernel_size = 3, batchnorm = batchnorm, activation=activation)
    c5 = conv2d_block(c5, n_filters = n_filters * 16, kernel_size = 3, batchnorm = batchnorm, activation=activation)
    p5 = Dropout(dropout)(c5) # 14x14x1024
    ## Upscaling

    ## Block6: 512, 512
    up6 = UpSampling2D(size=(2, 2),data_format=IMAGE_ORDERING, interpolation="bilinear")(p5) # 28x28x1024
    u6 = Conv2D(filters=n_filters*8, kernel_size=2, data_format=IMAGE_ORDERING,
                activation="relu", padding="same", kernel_initializer="he_normal")(up6)
    m6 = Concatenate(axis=3)([u6, c4])
    m6 = BatchNormalization()(m6)
    c6 = conv2d_block(m6, n_filters * 8, kernel_size = 3, batchnorm = batchnorm, activation=activation)
    
    ## Block7: 256, 256
    up7 = UpSampling2D(size=(2, 2),data_format=IMAGE_ORDERING, interpolation="bilinear")(c6) #56x56x256
    u7 = Conv2D(filters=n_filters*4, kernel_size=2, data_format=IMAGE_ORDERING,
                activation="relu", padding="same", kernel_initializer="he_normal")(up7)
    m7 = Concatenate(axis=3)([u7, c3])
    m7 = BatchNormalization()(m7)
    c7 = conv2d_block(m7, n_filters * 4, kernel_size = 3, batchnorm = batchnorm, activation=activation)
    
    ## Block8: 128, 128
    up8 = UpSampling2D(size=(2, 2),data_format=IMAGE_ORDERING, interpolation="bilinear")(c7) # 112x112x128
    u8  = Conv2D(filters=n_filters*2, kernel_size=2, data_format=IMAGE_ORDERING,
                activation="relu", padding="same", kernel_initializer="he_normal")(up8)
    m8  = Concatenate(axis=3)([u8, c2])
    m8 = BatchNormalization()(m8)
    c8 = conv2d_block(m8, n_filters * 2, kernel_size = 3, batchnorm = batchnorm, activation=activation)
    
    ## Block9: 64, 64
    up9 = UpSampling2D(size=(2, 2),data_format=IMAGE_ORDERING, interpolation="bilinear")(c8) # 224x224x64
    u9  = Conv2D(filters=n_filters*1, kernel_size=2, data_format=IMAGE_ORDERING,
                activation="relu", padding="same", kernel_initializer="he_normal")(up9)
    m9 = Concatenate(axis=3)([u9, c1])
    m9 = BatchNormalization()(m9)
    c9 = conv2d_block(m9, n_filters * 1, kernel_size = 3, batchnorm = batchnorm, activation=activation)
    
    ## Last layers
    c10 = Conv2D(filters=nClasses, kernel_size=1, data_format=IMAGE_ORDERING)(c9)
    o = (Activation("softmax"))(c10)
    model = Model(inputs=img_input, outputs=o)

    return model
