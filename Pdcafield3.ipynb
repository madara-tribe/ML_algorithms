# %% [markdown]
# <a href="https://colab.research.google.com/github/madara-tribe/ML_algorithms/blob/master/Pdcafield.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt
#import seaborn as sns
from keras import optimizers
## Import usual libraries
import tensorflow as tf
import keras, sys, time, warnings
from keras.models import *
from keras.layers import *
from keras import optimizers
from keras import backend
from datetime import datetime #DB
import gc #DB
from tqdm import tqdm
from sklearn.utils import shuffle
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import LearningRateScheduler, ReduceLROnPlateau
warnings.filterwarnings("ignore")



PLUS=60
# like UNET_v1 but with a Conv2D layer betweeb UpSampling2D aand Concatenate layers
def UNET_v2( nClasses, input_height, input_width, n_filters=16*2, dropout=0.1):

    ## input_height and width must be devisible by 16 because maxpooling with filter size = (2,2) is operated 4 times,
    ## which makes the input_height and width 2^4 = 16 times smaller
    assert input_height%16 == 0
    assert input_width%16 == 0

    img_input = Input(shape=(input_height,input_width, 3)) ## Assume 224,224,3
    ## Downscaling

    ## Block 1: 64, 64
    c1 = conv2d_block(img_input, n_filters * 1, kernel_size = 3)
    c1 = conv2d_block(c1, n_filters * 1, kernel_size = 3)
    p1 = MaxPooling2D((2, 2))(c1)
    p1 = Dropout(dropout)(p1) # 112x112x64

    ## Block 2: 128, 128
    c2 = conv2d_block(p1, n_filters * 2, kernel_size = 3)
    c2 = conv2d_block(c2, n_filters * 2, kernel_size = 3)
    p2 = MaxPooling2D((2, 2))(c2)
    p2 = Dropout(dropout)(p2) # 56x56x128

    ## Block 3: 256, 256
    c3 = conv2d_block(p2, n_filters * 4, kernel_size = 3)
    c3 = conv2d_block(c3, n_filters * 4, kernel_size = 3)
    p3 = MaxPooling2D((2, 2))(c3)
    p3 = Dropout(dropout)(p3) # 28x28x256

    ## Block 4: 512, 512
    c4 = conv2d_block(p3, n_filters * 8, kernel_size = 3)
    c4 = conv2d_block(c4, n_filters * 8, kernel_size = 3)
    p4 = MaxPooling2D((2, 2))(c4)
    p4 = Dropout(dropout)(p4) # 14x14x512

    ## Block5: 1024, 1024
    c5 = conv2d_block(p4, n_filters = (n_filters * 16)+PLUS, kernel_size = 3)
    c5 = conv2d_block(c5, n_filters = (n_filters * 16)+PLUS, kernel_size = 3)
    p5 = Dropout(dropout)(c5) # 14x14x1024
    ## Upscaling

    ## Block6: 512, 512
    up6 = UpSampling2D(size=(2, 2), interpolation="bilinear")(p5) # 28x28x1024
    u6 = Conv2D(filters=n_filters*8, kernel_size=2, activation=None, padding="same", kernel_initializer="he_normal")(up6)
    m6 = Concatenate(axis=3)([u6, c4])
    m6 = BatchNormalization()(m6)
    c6 = conv2d_block(m6, n_filters * 8, kernel_size = 3)
    
    ## Block7: 256, 256
    up7 = UpSampling2D(size=(2, 2), interpolation="bilinear")(c6) #56x56x256
    u7 = Conv2D(filters=n_filters*4, kernel_size=2, activation=None, padding="same", kernel_initializer="he_normal")(up7)
    m7 = Concatenate(axis=3)([u7, c3])
    m7 = BatchNormalization()(m7)
    c7 = conv2d_block(m7, n_filters * 4, kernel_size = 3)
    
    ## Block8: 128, 128
    up8 = UpSampling2D(size=(2, 2), interpolation="bilinear")(c7) # 112x112x128
    u8  = Conv2D(filters=n_filters*2, kernel_size=2, activation=None, padding="same", kernel_initializer="he_normal")(up8)
    m8  = Concatenate(axis=3)([u8, c2])
    m8 = BatchNormalization()(m8)
    c8 = conv2d_block(m8, n_filters * 2, kernel_size = 3)
    
    ## Block9: 64, 64
    up9 = UpSampling2D(size=(2, 2), interpolation="bilinear")(c8) # 224x224x64
    u9  = Conv2D(filters=n_filters*1, kernel_size=2, activation=None, padding="same", kernel_initializer="he_normal")(up9)
    m9 = Concatenate(axis=3)([u9, c1])
    m9 = BatchNormalization()(m9)
    c9 = conv2d_block(m9, n_filters * 1, kernel_size = 3)
    
    ## Last layers
    c10 = Conv2D(filters=nClasses, kernel_size=1)(c9)
    o = (Activation("softmax"))(c10)
    model = Model(inputs=img_input, outputs=o)

    return model


N=160
HEIGHT = int(400-N)
WIDTH  = int(640-N)
print(HEIGHT, WIDTH)
N_CLASSES = 5

BATCH_SIZE = 2
EPOCHS = 100

weight_path='keras_model/fst.hdf5'
model_type = 2
model = UNET_v2(N_CLASSES, HEIGHT, WIDTH)
#model.load_weights(weight_path)
model.summary()
# Out:
# 240 480
# Model: "functional_7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 240, 480, 3) 0
# __________________________________________________________________________________________________
# conv2d_99 (Conv2D)              (None, 240, 480, 32) 896         input_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_96 (BatchNo (None, 240, 480, 32) 128         conv2d_99[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 240, 480, 32) 0           batch_normalization_96[0][0]
# __________________________________________________________________________________________________
# conv2d_100 (Conv2D)             (None, 240, 480, 32) 9248        activation_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_97 (BatchNo (None, 240, 480, 32) 128         conv2d_100[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 240, 480, 32) 0           batch_normalization_97[0][0]
# __________________________________________________________________________________________________
# conv2d_101 (Conv2D)             (None, 240, 480, 32) 9248        activation_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_98 (BatchNo (None, 240, 480, 32) 128         conv2d_101[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 240, 480, 32) 0           batch_normalization_98[0][0]
# __________________________________________________________________________________________________
# conv2d_102 (Conv2D)             (None, 240, 480, 32) 9248        activation_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_99 (BatchNo (None, 240, 480, 32) 128         conv2d_102[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 240, 480, 32) 0           batch_normalization_99[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 120, 240, 32) 0           activation_90[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 120, 240, 32) 0           max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_103 (Conv2D)             (None, 120, 240, 64) 18496       dropout_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_100 (BatchN (None, 120, 240, 64) 256         conv2d_103[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 120, 240, 64) 0           batch_normalization_100[0][0]
# __________________________________________________________________________________________________
# conv2d_104 (Conv2D)             (None, 120, 240, 64) 36928       activation_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_101 (BatchN (None, 120, 240, 64) 256         conv2d_104[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 120, 240, 64) 0           batch_normalization_101[0][0]
# __________________________________________________________________________________________________
# conv2d_105 (Conv2D)             (None, 120, 240, 64) 36928       activation_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_102 (BatchN (None, 120, 240, 64) 256         conv2d_105[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 120, 240, 64) 0           batch_normalization_102[0][0]
# __________________________________________________________________________________________________
# conv2d_106 (Conv2D)             (None, 120, 240, 64) 36928       activation_93[0][0]
# __________________________________________________________________________________________________
# batch_normalization_103 (BatchN (None, 120, 240, 64) 256         conv2d_106[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 120, 240, 64) 0           batch_normalization_103[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 60, 120, 64)  0           activation_94[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 60, 120, 64)  0           max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_107 (Conv2D)             (None, 60, 120, 128) 73856       dropout_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104 (BatchN (None, 60, 120, 128) 512         conv2d_107[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, 60, 120, 128) 0           batch_normalization_104[0][0]
# __________________________________________________________________________________________________
# conv2d_108 (Conv2D)             (None, 60, 120, 128) 147584      activation_95[0][0]
# __________________________________________________________________________________________________
# batch_normalization_105 (BatchN (None, 60, 120, 128) 512         conv2d_108[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, 60, 120, 128) 0           batch_normalization_105[0][0]
# __________________________________________________________________________________________________
# conv2d_109 (Conv2D)             (None, 60, 120, 128) 147584      activation_96[0][0]
# __________________________________________________________________________________________________
# batch_normalization_106 (BatchN (None, 60, 120, 128) 512         conv2d_109[0][0]
# __________________________________________________________________________________________________
# activation_97 (Activation)      (None, 60, 120, 128) 0           batch_normalization_106[0][0]
# __________________________________________________________________________________________________
# conv2d_110 (Conv2D)             (None, 60, 120, 128) 147584      activation_97[0][0]
# __________________________________________________________________________________________________
# batch_normalization_107 (BatchN (None, 60, 120, 128) 512         conv2d_110[0][0]
# __________________________________________________________________________________________________
# activation_98 (Activation)      (None, 60, 120, 128) 0           batch_normalization_107[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (None, 30, 60, 128)  0           activation_98[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 30, 60, 128)  0           max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_111 (Conv2D)             (None, 30, 60, 256)  295168      dropout_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_108 (BatchN (None, 30, 60, 256)  1024        conv2d_111[0][0]
# __________________________________________________________________________________________________
# activation_99 (Activation)      (None, 30, 60, 256)  0           batch_normalization_108[0][0]
# __________________________________________________________________________________________________
# conv2d_112 (Conv2D)             (None, 30, 60, 256)  590080      activation_99[0][0]
# __________________________________________________________________________________________________
# batch_normalization_109 (BatchN (None, 30, 60, 256)  1024        conv2d_112[0][0]
# __________________________________________________________________________________________________
# activation_100 (Activation)     (None, 30, 60, 256)  0           batch_normalization_109[0][0]
# __________________________________________________________________________________________________
# conv2d_113 (Conv2D)             (None, 30, 60, 256)  590080      activation_100[0][0]
# __________________________________________________________________________________________________
# batch_normalization_110 (BatchN (None, 30, 60, 256)  1024        conv2d_113[0][0]
# __________________________________________________________________________________________________
# activation_101 (Activation)     (None, 30, 60, 256)  0           batch_normalization_110[0][0]
# __________________________________________________________________________________________________
# conv2d_114 (Conv2D)             (None, 30, 60, 256)  590080      activation_101[0][0]
# __________________________________________________________________________________________________
# batch_normalization_111 (BatchN (None, 30, 60, 256)  1024        conv2d_114[0][0]
# __________________________________________________________________________________________________
# activation_102 (Activation)     (None, 30, 60, 256)  0           batch_normalization_111[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 15, 30, 256)  0           activation_102[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 15, 30, 256)  0           max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_115 (Conv2D)             (None, 15, 30, 572)  1318460     dropout_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_112 (BatchN (None, 15, 30, 572)  2288        conv2d_115[0][0]
# __________________________________________________________________________________________________
# activation_103 (Activation)     (None, 15, 30, 572)  0           batch_normalization_112[0][0]
# __________________________________________________________________________________________________
# conv2d_116 (Conv2D)             (None, 15, 30, 572)  2945228     activation_103[0][0]
# __________________________________________________________________________________________________
# batch_normalization_113 (BatchN (None, 15, 30, 572)  2288        conv2d_116[0][0]
# __________________________________________________________________________________________________
# activation_104 (Activation)     (None, 15, 30, 572)  0           batch_normalization_113[0][0]
# __________________________________________________________________________________________________
# conv2d_117 (Conv2D)             (None, 15, 30, 572)  2945228     activation_104[0][0]
# __________________________________________________________________________________________________
# batch_normalization_114 (BatchN (None, 15, 30, 572)  2288        conv2d_117[0][0]
# __________________________________________________________________________________________________
# activation_105 (Activation)     (None, 15, 30, 572)  0           batch_normalization_114[0][0]
# __________________________________________________________________________________________________
# conv2d_118 (Conv2D)             (None, 15, 30, 572)  2945228     activation_105[0][0]
# __________________________________________________________________________________________________
# batch_normalization_115 (BatchN (None, 15, 30, 572)  2288        conv2d_118[0][0]
# __________________________________________________________________________________________________
# activation_106 (Activation)     (None, 15, 30, 572)  0           batch_normalization_115[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 15, 30, 572)  0           activation_106[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_12 (UpSampling2D) (None, 30, 60, 572)  0           dropout_19[0][0]
# __________________________________________________________________________________________________
# conv2d_119 (Conv2D)             (None, 30, 60, 256)  585984      up_sampling2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 30, 60, 512)  0           conv2d_119[0][0]
#                                                                  activation_102[0][0]
# __________________________________________________________________________________________________
# batch_normalization_116 (BatchN (None, 30, 60, 512)  2048        concatenate_12[0][0]
# __________________________________________________________________________________________________
# conv2d_120 (Conv2D)             (None, 30, 60, 256)  1179904     batch_normalization_116[0][0]
# __________________________________________________________________________________________________
# batch_normalization_117 (BatchN (None, 30, 60, 256)  1024        conv2d_120[0][0]
# __________________________________________________________________________________________________
# activation_107 (Activation)     (None, 30, 60, 256)  0           batch_normalization_117[0][0]
# __________________________________________________________________________________________________
# conv2d_121 (Conv2D)             (None, 30, 60, 256)  590080      activation_107[0][0]
# __________________________________________________________________________________________________
# batch_normalization_118 (BatchN (None, 30, 60, 256)  1024        conv2d_121[0][0]
# __________________________________________________________________________________________________
# activation_108 (Activation)     (None, 30, 60, 256)  0           batch_normalization_118[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_13 (UpSampling2D) (None, 60, 120, 256) 0           activation_108[0][0]
# __________________________________________________________________________________________________
# conv2d_122 (Conv2D)             (None, 60, 120, 128) 131200      up_sampling2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 60, 120, 256) 0           conv2d_122[0][0]
#                                                                  activation_98[0][0]
# __________________________________________________________________________________________________
# batch_normalization_119 (BatchN (None, 60, 120, 256) 1024        concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv2d_123 (Conv2D)             (None, 60, 120, 128) 295040      batch_normalization_119[0][0]
# __________________________________________________________________________________________________
# batch_normalization_120 (BatchN (None, 60, 120, 128) 512         conv2d_123[0][0]
# __________________________________________________________________________________________________
# activation_109 (Activation)     (None, 60, 120, 128) 0           batch_normalization_120[0][0]
# __________________________________________________________________________________________________
# conv2d_124 (Conv2D)             (None, 60, 120, 128) 147584      activation_109[0][0]
# __________________________________________________________________________________________________
# batch_normalization_121 (BatchN (None, 60, 120, 128) 512         conv2d_124[0][0]
# __________________________________________________________________________________________________
# activation_110 (Activation)     (None, 60, 120, 128) 0           batch_normalization_121[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_14 (UpSampling2D) (None, 120, 240, 128 0           activation_110[0][0]
# __________________________________________________________________________________________________
# conv2d_125 (Conv2D)             (None, 120, 240, 64) 32832       up_sampling2d_14[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 120, 240, 128 0           conv2d_125[0][0]
#                                                                  activation_94[0][0]
# __________________________________________________________________________________________________
# batch_normalization_122 (BatchN (None, 120, 240, 128 512         concatenate_14[0][0]
# __________________________________________________________________________________________________
# conv2d_126 (Conv2D)             (None, 120, 240, 64) 73792       batch_normalization_122[0][0]
# __________________________________________________________________________________________________
# batch_normalization_123 (BatchN (None, 120, 240, 64) 256         conv2d_126[0][0]
# __________________________________________________________________________________________________
# activation_111 (Activation)     (None, 120, 240, 64) 0           batch_normalization_123[0][0]
# __________________________________________________________________________________________________
# conv2d_127 (Conv2D)             (None, 120, 240, 64) 36928       activation_111[0][0]
# __________________________________________________________________________________________________
# batch_normalization_124 (BatchN (None, 120, 240, 64) 256         conv2d_127[0][0]
# __________________________________________________________________________________________________
# activation_112 (Activation)     (None, 120, 240, 64) 0           batch_normalization_124[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_15 (UpSampling2D) (None, 240, 480, 64) 0           activation_112[0][0]
# __________________________________________________________________________________________________
# conv2d_128 (Conv2D)             (None, 240, 480, 32) 8224        up_sampling2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 240, 480, 64) 0           conv2d_128[0][0]
#                                                                  activation_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_125 (BatchN (None, 240, 480, 64) 256         concatenate_15[0][0]
# __________________________________________________________________________________________________
# conv2d_129 (Conv2D)             (None, 240, 480, 32) 18464       batch_normalization_125[0][0]
# __________________________________________________________________________________________________
# batch_normalization_126 (BatchN (None, 240, 480, 32) 128         conv2d_129[0][0]
# __________________________________________________________________________________________________
# activation_113 (Activation)     (None, 240, 480, 32) 0           batch_normalization_126[0][0]
# __________________________________________________________________________________________________
# conv2d_130 (Conv2D)             (None, 240, 480, 32) 9248        activation_113[0][0]
# __________________________________________________________________________________________________
# batch_normalization_127 (BatchN (None, 240, 480, 32) 128         conv2d_130[0][0]
# __________________________________________________________________________________________________
# activation_114 (Activation)     (None, 240, 480, 32) 0           batch_normalization_127[0][0]
# __________________________________________________________________________________________________
# conv2d_131 (Conv2D)             (None, 240, 480, 5)  165         activation_114[0][0]
# __________________________________________________________________________________________________
# activation_115 (Activation)     (None, 240, 480, 5)  0           conv2d_131[0][0]
# ==================================================================================================
# Total params: 16,028,037
# Trainable params: 16,015,781
# Non-trainable params: 12,256
# __________________________________________________________________________________________________

# %%
path='/content/drive/MyDrive/4cls/'
dir_train_img=path+'train'
dir_train_seg=path+'anno'
dir_valid_img = path+'val'
dir_valid_seg = path+'val_anno'

def noise_chale(bgr):
    ksize = 3
    #plt.imshow(bgr),plt.show()
    lab = cv2.cvtColor(bgr, cv2.COLOR_BGR2LAB)
    #plt.imshow(lab),plt.show()
    lab_planes = cv2.split(lab)
    lab_planes[0] = cv2.medianBlur(lab_planes[0], ksize)
    lab = cv2.merge(lab_planes)
    return cv2.cvtColor(lab, cv2.COLOR_LAB2BGR)
	


def flipud_image(X, Y):
    Xflip =np.array([img[::-1] for img in X])
    Yflip =np.array([img[::-1] for img in Y])
    return Xflip, Yflip
    
def fliplr_image(X, Y):
    Xflip =np.array([img[:, ::-1] for img in X])
    Yflip =np.array([img[:, ::-1] for img in Y])
    return Xflip, Yflip

def salt(img):
    row,col,ch = img.shape
    s_vs_p = 0.5
    amount = 0.004
    sp_img = img.copy()
    # pepper
    num_pepper = np.ceil(amount* img.size * (1. - s_vs_p))
    coords = [np.random.randint(0, i-1 , int(num_pepper)) for i in img.shape]
    sp_img[coords[:-1]] = (0,0,0)
    return sp_img
	
	
def channel_shift(img, value):
    value = int(random.uniform(-value, value))
    img = img + value
    img[:,:,:][img[:,:,:]>255]  = 255
    img[:,:,:][img[:,:,:]<0]  = 0
    #img = img.astype(np.uint8)
    return img

def contrast(img, gamma = 0.5):
    gamma_cvt = np.zeros((256,1),dtype = 'uint8')
 
    for i in range(256):
        gamma_cvt[i][0] = 255 * (float(i)/255) ** (1.0/gamma)
    return cv2.LUT(img, gamma_cvt)

def sift_angle(image, y_move_ratio=0, x_move_ratio=0, angle_ratio=float(np.pi/60)):
    h, w, _ = np.shape(image)
    size = tuple(np.array([w, h]))
    print(size)
    #np.pi=3.141592653589793
    rad=angle_ratio
    move_x = x_move_ratio
    move_y = w * y_move_ratio

    matrix = [[np.cos(rad), -1 * np.sin(rad), move_x],
                   [np.sin(rad), np.cos(rad), move_y]]

    affine_matrix = np.float32(matrix)
    chage_angle = cv2.warpAffine(image, affine_matrix, size, flags=cv2.INTER_LINEAR)
    return chage_angle

def clahe(bgr):
    #plt.imshow(bgr),plt.show()
    lab = cv2.cvtColor(bgr, cv2.COLOR_BGR2LAB)
    #plt.imshow(lab),plt.show()
    lab_planes = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=10.0,tileGridSize=(8,8))
    lab_planes[0] = clahe.apply(lab_planes[0])
    lab = cv2.merge(lab_planes)
    return cv2.cvtColor(lab, cv2.COLOR_LAB2BGR)


def ContrastNormalizeImageArr(path, H, W, gamma=1.8):
    NORM_FACTOR = 255
    img = cv2.imread(path, 1)
    img = contrast(img, gamma = gamma)
    img = cv2.resize(img, (H, W), interpolation=cv2.INTER_NEAREST)
    img = img.astype(np.float32)
    img = img/NORM_FACTOR
    return img
def noise(img):
	ksize = 3
	for j in range(3):
		img[:,:,j]=cv2.medianBlur(img[:, :, j], ksize)
	return img


def NormalizeImageArr(path, H, W, aug_type=None):
    aug_type = aug_type
    NORM_FACTOR = 255
    img = cv2.imread(path, 1)
    img = cv2.resize(img, (H, W), interpolation=cv2.INTER_NEAREST)
    if img.mean()<80:
        img = clahe(img)
    else: 
        img = noise_chale(img)
    
    if aug_type == 'pepper':
        img = salt(img)
    elif aug_type == 'sift':
        img = channel_shift(img, 60)
    else:
        pass
    img = img.astype(np.float32)
    img = img/NORM_FACTOR
    return img

def LoadSegmentationArr( path , nClasses,  width ,height):
    seg_labels = np.zeros((height, width, nClasses))
    img = cv2.imread(path, 1)
    img = cv2.resize(img, (width, height), interpolation=cv2.INTER_NEAREST)
    img = img[:, : , 0]
    for c in range(nClasses):
        seg_labels[: , : , c ] = (img == c ).astype(int)
    return seg_labels

print('train load')
train_images = os.listdir(dir_train_img)
train_images.sort()
train_segmentations  = os.listdir(dir_train_seg)
train_segmentations.sort()
X_train, Y_train=[], []

for im , seg in tqdm(zip(train_images[:25], train_segmentations[:25])):
    X_train.append(NormalizeImageArr(os.path.join(dir_train_img,im), WIDTH, HEIGHT, aug_type=None))
    Y_train.append(LoadSegmentationArr( os.path.join(dir_train_seg,seg), N_CLASSES, WIDTH, HEIGHT)  )

X_train, Y_train = np.array(X_train), np.array(Y_train)
#X1, Y1 = fliplr_image(X_train, Y_train)
#X_train = np.vstack([X_train, X1])

#X_train, Y_train = shuffle(X_train, Y_train)
print(X_train.shape,Y_train.shape)
print(X_train.max(), X_train.min())

# In[13]:


# load validation images
valid_images = os.listdir(dir_valid_img)
valid_images.sort()
valid_segmentations  = os.listdir(dir_valid_seg)
valid_segmentations.sort()
X_valid, Y_valid = [], []

for im , seg in tqdm(zip(valid_images,valid_segmentations)):
    X_valid.append(NormalizeImageArr(os.path.join(dir_valid_img,im), WIDTH, HEIGHT) )
    Y_valid.append(LoadSegmentationArr( os.path.join(dir_valid_seg,seg) , N_CLASSES, WIDTH, HEIGHT))


X_valid, Y_valid = np.array(X_valid), np.array(Y_valid)
#Xv1, Yv1 = fliplr_image(X_valid, Y_valid)
#X_valid = np.vstack([X_valid, Xv1])
#Y_valid = np.vstack([Y_valid, Yv1])
print(X_valid.shape,Y_valid.shape)
print(X_valid.max(),X_valid.min())
plt.imshow(X_train[5]),plt.show()
plt.imshow(X_valid[2]),plt.show()
# Out:
# 2it [00:00, 14.29it/s]
# train load
# 25it [00:01, 14.69it/s]
# 2it [00:00, 14.90it/s]
# (25, 240, 480, 3) (25, 240, 480, 5)
# 1.0 0.0
# 10it [00:00, 14.40it/s]
# (10, 240, 480, 3) (10, 240, 480, 5)
# 1.0 0.0
# (<matplotlib.image.AxesImage at 0x7f65ba35a828>, None)

# %%
checkpoint_path = "train_ck/cp-{epoch:04d}.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)
 
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    checkpoint_path, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True, period=1)


reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, verbose=1)
callback = [reduce_lr]

adam=optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0)
model.compile(loss='categorical_crossentropy',
              optimizer=adam,
              metrics=['accuracy'])
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
startTime1 = datetime.now() #DB
hist1 = model.fit(X_train,Y_train, validation_data=(X_valid,Y_valid), 
                  batch_size=2,epochs=200)
endTime1 = datetime.now()
diff1 = endTime1 - startTime1
print("\n")
print("Elapsed time for Keras training (s): ", diff1.total_seconds())
print("\n")

for key in ["loss", "val_loss"]:
    plt.plot(hist1.history[key],label=key)
plt.legend()

print("\nEnd of UNET training\n")
# Out:
# Epoch 1/200
# 13/13 [==============================] - ETA: 0s - loss: 1.2563 - accuracy: 0.5976WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0067s vs `on_test_batch_end` time: 0.0372s). Check your callbacks.
# 13/13 [==============================] - 3s 209ms/step - loss: 1.2563 - accuracy: 0.5976 - val_loss: 6.8933 - val_accuracy: 0.5721
# Epoch 2/200
# 13/13 [==============================] - 2s 164ms/step - loss: 0.7620 - accuracy: 0.8410 - val_loss: 15.9180 - val_accuracy: 0.0112
# Epoch 3/200
# 13/13 [==============================] - 2s 164ms/step - loss: 0.5945 - accuracy: 0.8598 - val_loss: 14.4470 - val_accuracy: 0.0794
# Epoch 4/200
# 13/13 [==============================] - 2s 165ms/step - loss: 0.5140 - accuracy: 0.8736 - val_loss: 15.8795 - val_accuracy: 0.0111
# Epoch 5/200
# 13/13 [==============================] - 2s 165ms/step - loss: 0.4744 - accuracy: 0.8582 - val_loss: 15.8147 - val_accuracy: 0.0157
# Epoch 6/200
# 13/13 [==============================] - 2s 165ms/step - loss: 0.4210 - accuracy: 0.8691 - val_loss: 12.5630 - val_accuracy: 0.1555
# Epoch 7/200
# 13/13 [==============================] - 2s 166ms/step - loss: 0.3893 - accuracy: 0.8809 - val_loss: 6.0318 - val_accuracy: 0.4616
# Epoch 8/200
# 13/13 [==============================] - 2s 167ms/step - loss: 0.3740 - accuracy: 0.8762 - val_loss: 3.2265 - val_accuracy: 0.6963
# Epoch 9/200
# 13/13 [==============================] - 2s 166ms/step - loss: 0.3588 - accuracy: 0.8829 - val_loss: 15.0814 - val_accuracy: 0.0452
# Epoch 10/200
# 13/13 [==============================] - 2s 167ms/step - loss: 0.4098 - accuracy: 0.8616 - val_loss: 3.8766 - val_accuracy: 0.7594
# Epoch 11/200
# 13/13 [==============================] - 2s 168ms/step - loss: 0.3761 - accuracy: 0.8693 - val_loss: 15.0768 - val_accuracy: 0.0463
# Epoch 12/200
# 13/13 [==============================] - 2s 168ms/step - loss: 0.3587 - accuracy: 0.8689 - val_loss: 13.8761 - val_accuracy: 0.0972
# Epoch 13/200
# 13/13 [==============================] - 2s 168ms/step - loss: 0.3375 - accuracy: 0.8764 - val_loss: 12.4128 - val_accuracy: 0.1679
# Epoch 14/200
# 13/13 [==============================] - 2s 168ms/step - loss: 0.3289 - accuracy: 0.8802 - val_loss: 10.1327 - val_accuracy: 0.2709
# Epoch 15/200
# 13/13 [==============================] - 2s 169ms/step - loss: 0.3080 - accuracy: 0.8810 - val_loss: 8.4621 - val_accuracy: 0.3436
# Epoch 16/200
# 13/13 [==============================] - 2s 169ms/step - loss: 0.3242 - accuracy: 0.8726 - val_loss: 6.9915 - val_accuracy: 0.4435
# Epoch 17/200
# 13/13 [==============================] - 2s 169ms/step - loss: 0.3006 - accuracy: 0.8802 - val_loss: 4.7590 - val_accuracy: 0.5777
# Epoch 18/200
# 13/13 [==============================] - 2s 169ms/step - loss: 0.2970 - accuracy: 0.8852 - val_loss: 2.3909 - val_accuracy: 0.7209
# Epoch 19/200
# 13/13 [==============================] - 2s 170ms/step - loss: 0.3058 - accuracy: 0.8794 - val_loss: 1.9884 - val_accuracy: 0.7536
# Epoch 20/200
# 13/13 [==============================] - 2s 170ms/step - loss: 0.2727 - accuracy: 0.9002 - val_loss: 1.3114 - val_accuracy: 0.8387
# Epoch 21/200
# 13/13 [==============================] - 2s 170ms/step - loss: 0.2882 - accuracy: 0.8887 - val_loss: 2.1073 - val_accuracy: 0.7802
# Epoch 22/200
# 13/13 [==============================] - 2s 171ms/step - loss: 0.2720 - accuracy: 0.8933 - val_loss: 1.5044 - val_accuracy: 0.8216
# Epoch 23/200
# 13/13 [==============================] - 2s 171ms/step - loss: 0.2802 - accuracy: 0.8958 - val_loss: 1.0795 - val_accuracy: 0.8483
# Epoch 24/200
# 13/13 [==============================] - 2s 171ms/step - loss: 0.2702 - accuracy: 0.8940 - val_loss: 2.9741 - val_accuracy: 0.5559
# Epoch 25/200
# 13/13 [==============================] - 2s 171ms/step - loss: 0.2822 - accuracy: 0.8897 - val_loss: 1.2518 - val_accuracy: 0.8413
# Epoch 26/200
# 13/13 [==============================] - 2s 171ms/step - loss: 0.2587 - accuracy: 0.9015 - val_loss: 1.0996 - val_accuracy: 0.8338
# Epoch 27/200
# 13/13 [==============================] - 2s 171ms/step - loss: 0.2470 - accuracy: 0.9032 - val_loss: 1.2619 - val_accuracy: 0.8494
# Epoch 28/200
# 13/13 [==============================] - 2s 171ms/step - loss: 0.2361 - accuracy: 0.9125 - val_loss: 0.6373 - val_accuracy: 0.8685
# Epoch 29/200
# 13/13 [==============================] - 2s 171ms/step - loss: 0.2371 - accuracy: 0.9125 - val_loss: 0.5675 - val_accuracy: 0.8635
# Epoch 30/200
# 13/13 [==============================] - 2s 171ms/step - loss: 0.2265 - accuracy: 0.9131 - val_loss: 0.6220 - val_accuracy: 0.8134
# Epoch 31/200
# 13/13 [==============================] - 2s 171ms/step - loss: 0.2460 - accuracy: 0.9061 - val_loss: 0.5700 - val_accuracy: 0.8546
# Epoch 32/200
# 13/13 [==============================] - 2s 172ms/step - loss: 0.2349 - accuracy: 0.9075 - val_loss: 0.5493 - val_accuracy: 0.8284
# Epoch 33/200
# 13/13 [==============================] - 2s 172ms/step - loss: 0.2246 - accuracy: 0.9134 - val_loss: 0.6832 - val_accuracy: 0.8487
# Epoch 34/200
# 13/13 [==============================] - 2s 172ms/step - loss: 0.2283 - accuracy: 0.9152 - val_loss: 0.4944 - val_accuracy: 0.8587
# Epoch 35/200
# 13/13 [==============================] - 2s 173ms/step - loss: 0.2370 - accuracy: 0.9061 - val_loss: 1.0606 - val_accuracy: 0.7590
# Epoch 36/200
# 13/13 [==============================] - 2s 173ms/step - loss: 0.2268 - accuracy: 0.9146 - val_loss: 0.7595 - val_accuracy: 0.8304
# Epoch 37/200
# 13/13 [==============================] - 2s 173ms/step - loss: 0.2107 - accuracy: 0.9243 - val_loss: 0.5854 - val_accuracy: 0.8279
# Epoch 38/200
# 13/13 [==============================] - 2s 174ms/step - loss: 0.2254 - accuracy: 0.9160 - val_loss: 0.4892 - val_accuracy: 0.8710
# Epoch 39/200
# 13/13 [==============================] - 2s 174ms/step - loss: 0.2412 - accuracy: 0.9075 - val_loss: 0.8298 - val_accuracy: 0.8369
# Epoch 40/200
# 13/13 [==============================] - 2s 174ms/step - loss: 0.2226 - accuracy: 0.9144 - val_loss: 0.5929 - val_accuracy: 0.8403
# Epoch 41/200
# 13/13 [==============================] - 2s 174ms/step - loss: 0.2243 - accuracy: 0.9132 - val_loss: 0.5824 - val_accuracy: 0.8350
# Epoch 42/200
# 13/13 [==============================] - 2s 174ms/step - loss: 0.2199 - accuracy: 0.9144 - val_loss: 0.7223 - val_accuracy: 0.8138
# Epoch 43/200
# 13/13 [==============================] - 2s 174ms/step - loss: 0.1967 - accuracy: 0.9243 - val_loss: 0.5846 - val_accuracy: 0.8449
# Epoch 44/200
# 13/13 [==============================] - 2s 175ms/step - loss: 0.1791 - accuracy: 0.9370 - val_loss: 0.6402 - val_accuracy: 0.8560
# Epoch 45/200
# 13/13 [==============================] - 2s 176ms/step - loss: 0.1785 - accuracy: 0.9363 - val_loss: 0.5328 - val_accuracy: 0.8549
# Epoch 46/200
# 13/13 [==============================] - 2s 176ms/step - loss: 0.1843 - accuracy: 0.9321 - val_loss: 1.2315 - val_accuracy: 0.7844
# Epoch 47/200
# 13/13 [==============================] - 2s 176ms/step - loss: 0.1882 - accuracy: 0.9289 - val_loss: 0.9471 - val_accuracy: 0.8223
# Epoch 48/200
# 13/13 [==============================] - 2s 176ms/step - loss: 0.1793 - accuracy: 0.9349 - val_loss: 0.5885 - val_accuracy: 0.8436
# Epoch 49/200
# 13/13 [==============================] - 2s 175ms/step - loss: 0.1864 - accuracy: 0.9308 - val_loss: 0.4818 - val_accuracy: 0.8706
# Epoch 50/200
# 13/13 [==============================] - 2s 177ms/step - loss: 0.1969 - accuracy: 0.9261 - val_loss: 0.5898 - val_accuracy: 0.8525
# Epoch 51/200
# 13/13 [==============================] - 2s 177ms/step - loss: 0.1738 - accuracy: 0.9371 - val_loss: 0.4679 - val_accuracy: 0.8601
# Epoch 52/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.1762 - accuracy: 0.9373 - val_loss: 0.4396 - val_accuracy: 0.8808
# Epoch 53/200
# 13/13 [==============================] - 2s 177ms/step - loss: 0.1882 - accuracy: 0.9272 - val_loss: 1.2001 - val_accuracy: 0.8574
# Epoch 54/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.2098 - accuracy: 0.9217 - val_loss: 1.4644 - val_accuracy: 0.7959
# Epoch 55/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.1894 - accuracy: 0.9293 - val_loss: 0.8473 - val_accuracy: 0.8345
# Epoch 56/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.1819 - accuracy: 0.9342 - val_loss: 0.6776 - val_accuracy: 0.8248
# Epoch 57/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.1594 - accuracy: 0.9424 - val_loss: 0.6505 - val_accuracy: 0.8513
# Epoch 58/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.1659 - accuracy: 0.9400 - val_loss: 0.4596 - val_accuracy: 0.8672
# Epoch 59/200
# 13/13 [==============================] - 2s 177ms/step - loss: 0.1527 - accuracy: 0.9445 - val_loss: 0.4992 - val_accuracy: 0.8762
# Epoch 60/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.1400 - accuracy: 0.9489 - val_loss: 0.4749 - val_accuracy: 0.8683
# Epoch 61/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.1428 - accuracy: 0.9487 - val_loss: 0.4279 - val_accuracy: 0.8806
# Epoch 62/200
# 13/13 [==============================] - 2s 177ms/step - loss: 0.1326 - accuracy: 0.9545 - val_loss: 0.4065 - val_accuracy: 0.8868
# Epoch 63/200
# 13/13 [==============================] - 2s 177ms/step - loss: 0.1340 - accuracy: 0.9525 - val_loss: 0.3512 - val_accuracy: 0.8974
# Epoch 64/200
# 13/13 [==============================] - 2s 177ms/step - loss: 0.1260 - accuracy: 0.9565 - val_loss: 0.3243 - val_accuracy: 0.8969
# Epoch 65/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.1293 - accuracy: 0.9537 - val_loss: 0.3479 - val_accuracy: 0.8850
# Epoch 66/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.1677 - accuracy: 0.9401 - val_loss: 0.4081 - val_accuracy: 0.8728
# Epoch 67/200
# 13/13 [==============================] - 2s 177ms/step - loss: 0.2219 - accuracy: 0.9173 - val_loss: 0.5148 - val_accuracy: 0.8821
# Epoch 68/200
# 13/13 [==============================] - 2s 177ms/step - loss: 0.2319 - accuracy: 0.9126 - val_loss: 0.7396 - val_accuracy: 0.8488
# Epoch 69/200
# 13/13 [==============================] - 2s 176ms/step - loss: 0.1893 - accuracy: 0.9306 - val_loss: 0.5473 - val_accuracy: 0.8655
# Epoch 70/200
# 13/13 [==============================] - 2s 177ms/step - loss: 0.1777 - accuracy: 0.9360 - val_loss: 0.5626 - val_accuracy: 0.8629
# Epoch 71/200
# 13/13 [==============================] - 2s 177ms/step - loss: 0.1533 - accuracy: 0.9451 - val_loss: 0.5563 - val_accuracy: 0.8657
# Epoch 72/200
# 13/13 [==============================] - 2s 177ms/step - loss: 0.1521 - accuracy: 0.9469 - val_loss: 0.3856 - val_accuracy: 0.8884
# Epoch 73/200
# 13/13 [==============================] - 2s 177ms/step - loss: 0.1731 - accuracy: 0.9392 - val_loss: 0.4620 - val_accuracy: 0.8762
# Epoch 74/200
# 13/13 [==============================] - 2s 177ms/step - loss: 0.2102 - accuracy: 0.9173 - val_loss: 0.4433 - val_accuracy: 0.8565
# Epoch 75/200
# 13/13 [==============================] - 2s 177ms/step - loss: 0.2008 - accuracy: 0.9212 - val_loss: 0.3694 - val_accuracy: 0.8782
# Epoch 76/200
# 13/13 [==============================] - 2s 177ms/step - loss: 0.1597 - accuracy: 0.9412 - val_loss: 0.4074 - val_accuracy: 0.8683
# Epoch 77/200
# 13/13 [==============================] - 2s 177ms/step - loss: 0.1459 - accuracy: 0.9483 - val_loss: 0.4273 - val_accuracy: 0.8720
# Epoch 78/200
# 13/13 [==============================] - 2s 177ms/step - loss: 0.1392 - accuracy: 0.9498 - val_loss: 0.4222 - val_accuracy: 0.8696
# Epoch 79/200
# 13/13 [==============================] - 2s 177ms/step - loss: 0.1458 - accuracy: 0.9445 - val_loss: 0.3958 - val_accuracy: 0.8724
# Epoch 80/200
# 13/13 [==============================] - 2s 176ms/step - loss: 0.1289 - accuracy: 0.9544 - val_loss: 0.3495 - val_accuracy: 0.8779
# Epoch 81/200
# 13/13 [==============================] - 2s 176ms/step - loss: 0.1284 - accuracy: 0.9534 - val_loss: 0.4213 - val_accuracy: 0.8793
# Epoch 82/200
# 13/13 [==============================] - 2s 177ms/step - loss: 0.1250 - accuracy: 0.9550 - val_loss: 0.3606 - val_accuracy: 0.8832
# Epoch 83/200
# 13/13 [==============================] - 2s 177ms/step - loss: 0.1105 - accuracy: 0.9609 - val_loss: 0.4166 - val_accuracy: 0.8705
# Epoch 84/200
# 13/13 [==============================] - 2s 176ms/step - loss: 0.1090 - accuracy: 0.9611 - val_loss: 0.3379 - val_accuracy: 0.8986
# Epoch 85/200
# 13/13 [==============================] - 2s 176ms/step - loss: 0.1138 - accuracy: 0.9596 - val_loss: 0.3658 - val_accuracy: 0.8944
# Epoch 86/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.1194 - accuracy: 0.9572 - val_loss: 0.3160 - val_accuracy: 0.9034
# Epoch 87/200
# 13/13 [==============================] - 2s 176ms/step - loss: 0.1258 - accuracy: 0.9536 - val_loss: 0.3885 - val_accuracy: 0.8918
# Epoch 88/200
# 13/13 [==============================] - 2s 177ms/step - loss: 0.1327 - accuracy: 0.9508 - val_loss: 0.4671 - val_accuracy: 0.8723
# Epoch 89/200
# 13/13 [==============================] - 2s 177ms/step - loss: 0.1243 - accuracy: 0.9562 - val_loss: 0.4631 - val_accuracy: 0.8774
# Epoch 90/200
# 13/13 [==============================] - 2s 177ms/step - loss: 0.1141 - accuracy: 0.9585 - val_loss: 0.4648 - val_accuracy: 0.8735
# Epoch 91/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.1062 - accuracy: 0.9623 - val_loss: 0.3886 - val_accuracy: 0.8836
# Epoch 92/200
# 13/13 [==============================] - 2s 177ms/step - loss: 0.1024 - accuracy: 0.9624 - val_loss: 0.3447 - val_accuracy: 0.8993
# Epoch 93/200
# 13/13 [==============================] - 2s 177ms/step - loss: 0.0998 - accuracy: 0.9645 - val_loss: 0.3546 - val_accuracy: 0.8937
# Epoch 94/200
# 13/13 [==============================] - 2s 177ms/step - loss: 0.0968 - accuracy: 0.9661 - val_loss: 0.3638 - val_accuracy: 0.8932
# Epoch 95/200
# 13/13 [==============================] - 2s 177ms/step - loss: 0.0964 - accuracy: 0.9653 - val_loss: 0.4003 - val_accuracy: 0.8875
# Epoch 96/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.1072 - accuracy: 0.9620 - val_loss: 0.4893 - val_accuracy: 0.8889
# Epoch 97/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.1090 - accuracy: 0.9615 - val_loss: 0.4715 - val_accuracy: 0.8947
# Epoch 98/200
# 13/13 [==============================] - 2s 177ms/step - loss: 0.1550 - accuracy: 0.9436 - val_loss: 0.4575 - val_accuracy: 0.8863
# Epoch 99/200
# 13/13 [==============================] - 2s 177ms/step - loss: 0.1876 - accuracy: 0.9291 - val_loss: 0.6851 - val_accuracy: 0.7966
# Epoch 100/200
# 13/13 [==============================] - 2s 177ms/step - loss: 0.1696 - accuracy: 0.9365 - val_loss: 0.7710 - val_accuracy: 0.8692
# Epoch 101/200
# 13/13 [==============================] - 2s 177ms/step - loss: 0.1344 - accuracy: 0.9527 - val_loss: 0.7623 - val_accuracy: 0.8591
# Epoch 102/200
# 13/13 [==============================] - 2s 176ms/step - loss: 0.1097 - accuracy: 0.9616 - val_loss: 0.6356 - val_accuracy: 0.8644
# Epoch 103/200
# 13/13 [==============================] - 2s 177ms/step - loss: 0.1088 - accuracy: 0.9605 - val_loss: 0.4702 - val_accuracy: 0.8819
# Epoch 104/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.1036 - accuracy: 0.9626 - val_loss: 0.5840 - val_accuracy: 0.8799
# Epoch 105/200
# 13/13 [==============================] - 2s 177ms/step - loss: 0.1093 - accuracy: 0.9602 - val_loss: 0.5299 - val_accuracy: 0.8755
# Epoch 106/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.1024 - accuracy: 0.9635 - val_loss: 0.4982 - val_accuracy: 0.8813
# Epoch 107/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0940 - accuracy: 0.9663 - val_loss: 0.4786 - val_accuracy: 0.8950
# Epoch 108/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0898 - accuracy: 0.9687 - val_loss: 0.4396 - val_accuracy: 0.8904
# Epoch 109/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0834 - accuracy: 0.9701 - val_loss: 0.4154 - val_accuracy: 0.8922
# Epoch 110/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0794 - accuracy: 0.9712 - val_loss: 0.3646 - val_accuracy: 0.8980
# Epoch 111/200
# 13/13 [==============================] - 2s 177ms/step - loss: 0.0781 - accuracy: 0.9722 - val_loss: 0.3173 - val_accuracy: 0.9029
# Epoch 112/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0779 - accuracy: 0.9724 - val_loss: 0.3420 - val_accuracy: 0.9019
# Epoch 113/200
# 13/13 [==============================] - 2s 177ms/step - loss: 0.0770 - accuracy: 0.9730 - val_loss: 0.3362 - val_accuracy: 0.9063
# Epoch 114/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0744 - accuracy: 0.9739 - val_loss: 0.3338 - val_accuracy: 0.9014
# Epoch 115/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0751 - accuracy: 0.9729 - val_loss: 0.2924 - val_accuracy: 0.9095
# Epoch 116/200
# 13/13 [==============================] - 2s 177ms/step - loss: 0.0723 - accuracy: 0.9740 - val_loss: 0.3632 - val_accuracy: 0.8985
# Epoch 117/200
# 13/13 [==============================] - 2s 177ms/step - loss: 0.0787 - accuracy: 0.9718 - val_loss: 0.3321 - val_accuracy: 0.9020
# Epoch 118/200
# 13/13 [==============================] - 2s 177ms/step - loss: 0.1214 - accuracy: 0.9585 - val_loss: 0.4706 - val_accuracy: 0.8530
# Epoch 119/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.1334 - accuracy: 0.9524 - val_loss: 0.5741 - val_accuracy: 0.8470
# Epoch 120/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.1256 - accuracy: 0.9532 - val_loss: 0.9528 - val_accuracy: 0.7966
# Epoch 121/200
# 13/13 [==============================] - 2s 179ms/step - loss: 0.1363 - accuracy: 0.9499 - val_loss: 0.8793 - val_accuracy: 0.8264
# Epoch 122/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.1394 - accuracy: 0.9491 - val_loss: 0.5776 - val_accuracy: 0.8766
# Epoch 123/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.1157 - accuracy: 0.9575 - val_loss: 0.3354 - val_accuracy: 0.8930
# Epoch 124/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.1187 - accuracy: 0.9561 - val_loss: 0.6852 - val_accuracy: 0.8270
# Epoch 125/200
# 13/13 [==============================] - 2s 177ms/step - loss: 0.0991 - accuracy: 0.9651 - val_loss: 0.4988 - val_accuracy: 0.8758
# Epoch 126/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0856 - accuracy: 0.9696 - val_loss: 0.4674 - val_accuracy: 0.8935
# Epoch 127/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0796 - accuracy: 0.9716 - val_loss: 0.4442 - val_accuracy: 0.8893
# Epoch 128/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0900 - accuracy: 0.9676 - val_loss: 0.4790 - val_accuracy: 0.8869
# Epoch 129/200
# 13/13 [==============================] - 2s 177ms/step - loss: 0.0868 - accuracy: 0.9685 - val_loss: 0.3216 - val_accuracy: 0.9102
# Epoch 130/200
# 13/13 [==============================] - 2s 177ms/step - loss: 0.0853 - accuracy: 0.9686 - val_loss: 0.4046 - val_accuracy: 0.8878
# Epoch 131/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0777 - accuracy: 0.9718 - val_loss: 0.3336 - val_accuracy: 0.8924
# Epoch 132/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0766 - accuracy: 0.9723 - val_loss: 0.3368 - val_accuracy: 0.8954
# Epoch 133/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0685 - accuracy: 0.9755 - val_loss: 0.3418 - val_accuracy: 0.9030
# Epoch 134/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0657 - accuracy: 0.9766 - val_loss: 0.3188 - val_accuracy: 0.9032
# Epoch 135/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0629 - accuracy: 0.9777 - val_loss: 0.3379 - val_accuracy: 0.9077
# Epoch 136/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0601 - accuracy: 0.9784 - val_loss: 0.3430 - val_accuracy: 0.9052
# Epoch 137/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0604 - accuracy: 0.9785 - val_loss: 0.3442 - val_accuracy: 0.9030
# Epoch 138/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0655 - accuracy: 0.9765 - val_loss: 0.3303 - val_accuracy: 0.9087
# Epoch 139/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0620 - accuracy: 0.9781 - val_loss: 0.3529 - val_accuracy: 0.9016
# Epoch 140/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0600 - accuracy: 0.9789 - val_loss: 0.3757 - val_accuracy: 0.8990
# Epoch 141/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0597 - accuracy: 0.9788 - val_loss: 0.3501 - val_accuracy: 0.9054
# Epoch 142/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0556 - accuracy: 0.9804 - val_loss: 0.3405 - val_accuracy: 0.9058
# Epoch 143/200
# 13/13 [==============================] - 2s 177ms/step - loss: 0.0544 - accuracy: 0.9807 - val_loss: 0.3519 - val_accuracy: 0.9044
# Epoch 144/200
# 13/13 [==============================] - 2s 177ms/step - loss: 0.0559 - accuracy: 0.9801 - val_loss: 0.3541 - val_accuracy: 0.8981
# Epoch 145/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0554 - accuracy: 0.9801 - val_loss: 0.3304 - val_accuracy: 0.9068
# Epoch 146/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0533 - accuracy: 0.9810 - val_loss: 0.3508 - val_accuracy: 0.9039
# Epoch 147/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0514 - accuracy: 0.9820 - val_loss: 0.3448 - val_accuracy: 0.9034
# Epoch 148/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0509 - accuracy: 0.9822 - val_loss: 0.3684 - val_accuracy: 0.8994
# Epoch 149/200
# 13/13 [==============================] - 2s 177ms/step - loss: 0.0517 - accuracy: 0.9812 - val_loss: 0.3609 - val_accuracy: 0.9025
# Epoch 150/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0511 - accuracy: 0.9816 - val_loss: 0.3731 - val_accuracy: 0.9040
# Epoch 151/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0501 - accuracy: 0.9821 - val_loss: 0.3600 - val_accuracy: 0.9086
# Epoch 152/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0481 - accuracy: 0.9827 - val_loss: 0.3591 - val_accuracy: 0.9086
# Epoch 153/200
# 13/13 [==============================] - 2s 177ms/step - loss: 0.0499 - accuracy: 0.9818 - val_loss: 0.3964 - val_accuracy: 0.9038
# Epoch 154/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0509 - accuracy: 0.9814 - val_loss: 0.4162 - val_accuracy: 0.8952
# Epoch 155/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0502 - accuracy: 0.9818 - val_loss: 0.4131 - val_accuracy: 0.9031
# Epoch 156/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0508 - accuracy: 0.9816 - val_loss: 0.4242 - val_accuracy: 0.8967
# Epoch 157/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0508 - accuracy: 0.9819 - val_loss: 0.4193 - val_accuracy: 0.9010
# Epoch 158/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0535 - accuracy: 0.9805 - val_loss: 0.3916 - val_accuracy: 0.8990
# Epoch 159/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0558 - accuracy: 0.9804 - val_loss: 0.4438 - val_accuracy: 0.8986
# Epoch 160/200
# 13/13 [==============================] - 2s 179ms/step - loss: 0.0553 - accuracy: 0.9809 - val_loss: 0.4978 - val_accuracy: 0.8761
# Epoch 161/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0520 - accuracy: 0.9817 - val_loss: 0.4937 - val_accuracy: 0.8878
# Epoch 162/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0600 - accuracy: 0.9795 - val_loss: 0.5180 - val_accuracy: 0.8838
# Epoch 163/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0596 - accuracy: 0.9779 - val_loss: 0.5005 - val_accuracy: 0.8918
# Epoch 164/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0582 - accuracy: 0.9786 - val_loss: 0.4437 - val_accuracy: 0.9008
# Epoch 165/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0626 - accuracy: 0.9764 - val_loss: 0.5024 - val_accuracy: 0.8939
# Epoch 166/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0560 - accuracy: 0.9796 - val_loss: 0.4396 - val_accuracy: 0.9004
# Epoch 167/200
# 13/13 [==============================] - 2s 179ms/step - loss: 0.0525 - accuracy: 0.9812 - val_loss: 0.4205 - val_accuracy: 0.8963
# Epoch 168/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0484 - accuracy: 0.9824 - val_loss: 0.4349 - val_accuracy: 0.8848
# Epoch 169/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0453 - accuracy: 0.9838 - val_loss: 0.4352 - val_accuracy: 0.9043
# Epoch 170/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0456 - accuracy: 0.9835 - val_loss: 0.4121 - val_accuracy: 0.9022
# Epoch 171/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0567 - accuracy: 0.9794 - val_loss: 0.4301 - val_accuracy: 0.8964
# Epoch 172/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0656 - accuracy: 0.9759 - val_loss: 0.5622 - val_accuracy: 0.8684
# Epoch 173/200
# 13/13 [==============================] - 2s 179ms/step - loss: 0.0621 - accuracy: 0.9769 - val_loss: 0.5405 - val_accuracy: 0.8899
# Epoch 174/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0587 - accuracy: 0.9792 - val_loss: 0.4840 - val_accuracy: 0.8941
# Epoch 175/200
# 13/13 [==============================] - 2s 179ms/step - loss: 0.0544 - accuracy: 0.9796 - val_loss: 0.5398 - val_accuracy: 0.8854
# Epoch 176/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0524 - accuracy: 0.9800 - val_loss: 0.4594 - val_accuracy: 0.8943
# Epoch 177/200
# 13/13 [==============================] - 2s 179ms/step - loss: 0.0513 - accuracy: 0.9815 - val_loss: 0.3943 - val_accuracy: 0.9035
# Epoch 178/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0930 - accuracy: 0.9689 - val_loss: 0.4604 - val_accuracy: 0.8888
# Epoch 179/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.1527 - accuracy: 0.9443 - val_loss: 1.6722 - val_accuracy: 0.7265
# Epoch 180/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.1368 - accuracy: 0.9512 - val_loss: 4.3233 - val_accuracy: 0.5750
# Epoch 181/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.1257 - accuracy: 0.9537 - val_loss: 8.2393 - val_accuracy: 0.3835
# Epoch 182/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.1062 - accuracy: 0.9612 - val_loss: 6.6177 - val_accuracy: 0.4781
# Epoch 183/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0877 - accuracy: 0.9683 - val_loss: 3.9454 - val_accuracy: 0.6040
# Epoch 184/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0734 - accuracy: 0.9738 - val_loss: 1.8415 - val_accuracy: 0.7519
# Epoch 185/200
# 13/13 [==============================] - 2s 177ms/step - loss: 0.0756 - accuracy: 0.9718 - val_loss: 0.7047 - val_accuracy: 0.8574
# Epoch 186/200
# 13/13 [==============================] - 2s 177ms/step - loss: 0.0699 - accuracy: 0.9744 - val_loss: 0.7553 - val_accuracy: 0.8583
# Epoch 187/200
# 13/13 [==============================] - 2s 177ms/step - loss: 0.0690 - accuracy: 0.9737 - val_loss: 0.5783 - val_accuracy: 0.8796
# Epoch 188/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0596 - accuracy: 0.9787 - val_loss: 0.5967 - val_accuracy: 0.8810
# Epoch 189/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0545 - accuracy: 0.9801 - val_loss: 0.5757 - val_accuracy: 0.8867
# Epoch 190/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0511 - accuracy: 0.9813 - val_loss: 0.4882 - val_accuracy: 0.8881
# Epoch 191/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0464 - accuracy: 0.9832 - val_loss: 0.5012 - val_accuracy: 0.8830
# Epoch 192/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0442 - accuracy: 0.9838 - val_loss: 0.4122 - val_accuracy: 0.9005
# Epoch 193/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0450 - accuracy: 0.9835 - val_loss: 0.4252 - val_accuracy: 0.8940
# Epoch 194/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0429 - accuracy: 0.9843 - val_loss: 0.3999 - val_accuracy: 0.9000
# Epoch 195/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0438 - accuracy: 0.9840 - val_loss: 0.3870 - val_accuracy: 0.9031
# Epoch 196/200
# 13/13 [==============================] - 2s 179ms/step - loss: 0.0423 - accuracy: 0.9844 - val_loss: 0.4038 - val_accuracy: 0.9026
# Epoch 197/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0392 - accuracy: 0.9857 - val_loss: 0.3756 - val_accuracy: 0.9041
# Epoch 198/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0407 - accuracy: 0.9851 - val_loss: 0.3855 - val_accuracy: 0.9051
# Epoch 199/200
# 13/13 [==============================] - 2s 177ms/step - loss: 0.0400 - accuracy: 0.9853 - val_loss: 0.3812 - val_accuracy: 0.9074
# Epoch 200/200
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0412 - accuracy: 0.9846 - val_loss: 0.4036 - val_accuracy: 0.9027
#
#
# Elapsed time for Keras training (s):  474.883487
#
#
#
# End of UNET training

# %%
# names of classes
CLASS_NAMES = ("None", "Sky",
               "Wall",
               "Pole",
               "Road",
               "Sidewalk",
               "Vegetation",
               "Sign",
               "Fence",
               "vehicle",
               "Pedestrian")


EPOCHS = 200


#######################################################################################################

# colors for segmented classes
colorB = [128, 232, 70, 156, 153, 153,  30,   0,  35, 152, 180,  60,   0, 142, 70, 100, 100, 230,  32]
colorG = [ 64,  35, 70, 102, 153, 153, 170, 220, 142, 251, 130,  20,   0,   0,  0,  60,  80,   0,  11]
colorR = [128, 244, 70, 102, 190, 153, 250, 220, 107, 152,  70, 220, 255,   0,  0,   0,   0,   0, 119]
CLASS_COLOR = list()
for i in range(0, 19):
    CLASS_COLOR.append([colorR[i], colorG[i], colorB[i]])
COLORS = np.array(CLASS_COLOR, dtype="float32")


def give_color_to_seg_img(seg,n_classes):
    if len(seg.shape)==3:
        seg = seg[:,:,0]
    seg_img = np.zeros( (seg.shape[0],seg.shape[1],3) ).astype('float')
    #colors = sns.color_palette("hls", n_classes) #DB
    colors = COLORS #DB
    for c in range(n_classes):
        segc = (seg == c)
        seg_img[:,:,0] += (segc*( colors[c][0]/255.0 ))
        seg_img[:,:,1] += (segc*( colors[c][1]/255.0 ))
        seg_img[:,:,2] += (segc*( colors[c][2]/255.0 ))

    return(seg_img)

def IoU(Yi,y_predi):
    ## mean Intersection over Union
    ## Mean IoU = TP/(FN + TP + FP)
    IoUs = []
    Nclass = int(np.max(Yi)) + 1
    for c in range(Nclass):
        TP = np.sum( (Yi == c)&(y_predi == c))
        FP = np.sum( (Yi != c)&(y_predi == c))
        FN = np.sum( (Yi == c)&(y_predi != c))
        IoU = TP/float(TP + FP + FN)
        #print("class {:02.0f}: #TP={:7.0f}, #FP={:7.0f}, #FN={:7.0f}, IoU={:4.3f}".format(c,TP,FP,FN,IoU))
        print("class (%2d) %12.12s: #TP=%7.0f, #FP=%7.0f, #FN=%7.0f, IoU=%4.3f" % (c, CLASS_NAMES[c],TP,FP,FN,IoU))
        IoUs.append(IoU)
    mIoU = np.mean(IoUs)
    print("_________________")
    print("Mean IoU: {:4.3f}".format(mIoU))
    return


def get_images_and_labels(dir_img, dir_seg, n_classes, width, height ):
    images = os.listdir(dir_img)
    images.sort()
    segmentations  = os.listdir(dir_seg)
    segmentations.sort()
    X = [] # list of input images
    Y = [] # list of ground truth (gt)
    I = [] # List of image Filenames
    S = [] # List of gt filenames
    for im , seg in zip(images,segmentations) :
        img_filename = os.path.join(dir_img, im)
        seg_filename = os.path.join(dir_seg, seg)
        S.append(seg_filename)
        I.append(img_filename)
        X.append( NormalizeImageArr(img_filename)  )
        Y.append( LoadSegmentationArr( seg_filename, n_classes , width , height )  )
    X, Y = np.array(X) , np.array(Y)
    print("X tensor shape: ", X.shape, " Y tensor shape: ", Y.shape)
    return X, Y, I, S

def get_images(dir_img):
    images = os.listdir(dir_img)
    images.sort()
    X = []
    for im in images :
        img_filename = os.path.join(dir_img, im)
        X.append(NormalizeImageArr(img_filename)  )
    X = np.array(X)
    return X

#########################################################################################################
# Visualize the model performance

def visualize_model_performance(X_test, y_pred1_i, y_test1_i, n_classes):

    for k in range(5):

        i = k
        img_is  = (X_test[i] + 1)*(255.0/2)
        seg = y_pred1_i[i]
        segtest = y_test1_i[i]

        fig = plt.figure(figsize=(10,30))
        ax = fig.add_subplot(1,3,1)
        ax.imshow(img_is/255.0)
        ax.set_title("original")

        ax = fig.add_subplot(1,3,2)
        ax.imshow(give_color_to_seg_img(seg,n_classes))
        ax.set_title("predicted class")

        ax = fig.add_subplot(1,3,3)
        ax.imshow(give_color_to_seg_img(segtest,n_classes))
        ax.set_title("true class")

        

    plt.show()

# %%
print("\ncomputing IoU over testing data set:")
X_test =X_train
Y_test = Y_train
y_pred1   = model.predict(X_test, batch_size=2)
y_pred1_i = np.argmax(y_pred1, axis=3)
y_test1_i = np.argmax(Y_test, axis=3)
#print(y_test1_i.shape,y_pred1_i.shape)
IoU(y_test1_i, y_pred1_i)

print("\nnow computing IoU over validation data set:")
y_pred2 = model.predict(X_valid, batch_size=2)
y_pred2_i = np.argmax(y_pred2, axis=3)
y_test2_i = np.argmax(Y_valid, axis=3)
#print(y_test2_i.shape,y_pred2_i.shape)
IoU(y_test2_i,y_pred2_i)
visualize_model_performance(X_valid, y_pred2_i, y_test2_i,N_CLASSES)
visualize_model_performance(X_train, y_pred1_i, y_test1_i, N_CLASSES)
# Out:
# computing IoU over testing data set:
# class ( 0)         None: #TP=2239034, #FP=  25279, #FN=  14073, IoU=0.983
# class ( 1)          Sky: #TP=  63461, #FP=   8442, #FN=   5124, IoU=0.824
# class ( 2)         Wall: #TP=    231, #FP=      0, #FN=   2916, IoU=0.073
# class ( 3)         Pole: #TP=  20730, #FP=   2750, #FN=   6801, IoU=0.685
# class ( 4)         Road: #TP= 507816, #FP=  12257, #FN=  19814, IoU=0.941
# _________________
# Mean IoU: 0.701
#
# now computing IoU over validation data set:
# class ( 0)         None: #TP= 829123, #FP=  55667, #FN=  49507, IoU=0.887
# class ( 1)          Sky: #TP=   8569, #FP=   4864, #FN=  18659, IoU=0.267
# class ( 2)         Wall: #TP=      0, #FP=     12, #FN=    500, IoU=0.000
# class ( 3)         Pole: #TP=   1520, #FP=   5081, #FN=   4507, IoU=0.137
# class ( 4)         Road: #TP= 200678, #FP=  46486, #FN=  38937, IoU=0.701
# _________________
# Mean IoU: 0.399

# %%
import tensorflow as tf
import sys, time, warnings
import keras as keras
from keras.models import *
from keras.layers import *
#from keras.utils import plot_model #DB
warnings.filterwarnings("ignore")


IMAGE_ORDERING =  "channels_last"



#Function to add 2 convolutional layers with the parameters passed to it
def conv2d_block(input_tensor, n_filters, kernel_size = 3, batchnorm = True, activation=True):
    #firt layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),
               kernel_initializer = 'he_normal', padding = 'same', data_format=IMAGE_ORDERING)(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    if activation:
        x = Activation('relu')(x)
    # second layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),
               kernel_initializer = 'he_normal', padding = 'same', data_format=IMAGE_ORDERING)(x)
    if batchnorm:
        x = BatchNormalization()(x)
    if activation:
        x = Activation('relu')(x)

    return x

# like UNET_v1 but with a Conv2D layer betweeb UpSampling2D aand Concatenate layers
def UNET_v2( nClasses, input_height, input_width, n_filters=16*2, dropout=0.1,
          batchnorm=True, activation=True):

    ## input_height and width must be devisible by 16 because maxpooling with filter size = (2,2) is operated 4 times,
    ## which makes the input_height and width 2^4 = 16 times smaller
    assert input_height%16 == 0
    assert input_width%16 == 0

    img_input = Input(shape=(input_height,input_width, 3)) ## Assume 224,224,3
    ## Downscaling

    ## Block 1: 64, 64
    c1 = conv2d_block(img_input, n_filters * 1, kernel_size = 3, batchnorm = batchnorm, activation=activation)
    c1 = conv2d_block(c1, n_filters * 1, kernel_size = 3, batchnorm = batchnorm, activation=activation)
    p1 = MaxPooling2D((2, 2))(c1)
    p1 = Dropout(dropout)(p1) # 112x112x64

    ## Block 2: 128, 128
    c2 = conv2d_block(p1, n_filters * 2, kernel_size = 3, batchnorm = batchnorm,  activation=activation)
    c2 = conv2d_block(c2, n_filters * 2, kernel_size = 3, batchnorm = batchnorm,  activation=activation)
    p2 = MaxPooling2D((2, 2))(c2)
    p2 = Dropout(dropout)(p2) # 56x56x128

    ## Block 3: 256, 256
    c3 = conv2d_block(p2, n_filters * 4, kernel_size = 3, batchnorm = batchnorm,  activation=activation)
    c3 = conv2d_block(c3, n_filters * 4, kernel_size = 3, batchnorm = batchnorm,  activation=activation)
    p3 = MaxPooling2D((2, 2))(c3)
    p3 = Dropout(dropout)(p3) # 28x28x256

    ## Block 4: 512, 512
    c4 = conv2d_block(p3, n_filters * 8, kernel_size = 3, batchnorm = batchnorm,  activation=activation)
    c4 = conv2d_block(c4, n_filters * 8, kernel_size = 3, batchnorm = batchnorm,  activation=activation)
    p4 = MaxPooling2D((2, 2))(c4)
    p4 = Dropout(dropout)(p4) # 14x14x512

    ## Block5: 1024, 1024
    c5 = conv2d_block(p4, n_filters = n_filters * 16, kernel_size = 3, batchnorm = batchnorm, activation=activation)
    c5 = conv2d_block(c5, n_filters = n_filters * 16, kernel_size = 3, batchnorm = batchnorm, activation=activation)
    p5 = Dropout(dropout)(c5) # 14x14x1024
    ## Upscaling

    ## Block6: 512, 512
    up6 = UpSampling2D(size=(2, 2),data_format=IMAGE_ORDERING, interpolation="bilinear")(p5) # 28x28x1024
    u6 = Conv2D(filters=n_filters*8, kernel_size=2, data_format=IMAGE_ORDERING,
                activation="relu", padding="same", kernel_initializer="he_normal")(up6)
    m6 = Concatenate(axis=3)([u6, c4])
    m6 = BatchNormalization()(m6)
    c6 = conv2d_block(m6, n_filters * 8, kernel_size = 3, batchnorm = batchnorm, activation=activation)
    
    ## Block7: 256, 256
    up7 = UpSampling2D(size=(2, 2),data_format=IMAGE_ORDERING, interpolation="bilinear")(c6) #56x56x256
    u7 = Conv2D(filters=n_filters*4, kernel_size=2, data_format=IMAGE_ORDERING,
                activation="relu", padding="same", kernel_initializer="he_normal")(up7)
    m7 = Concatenate(axis=3)([u7, c3])
    m7 = BatchNormalization()(m7)
    c7 = conv2d_block(m7, n_filters * 4, kernel_size = 3, batchnorm = batchnorm, activation=activation)
    
    ## Block8: 128, 128
    up8 = UpSampling2D(size=(2, 2),data_format=IMAGE_ORDERING, interpolation="bilinear")(c7) # 112x112x128
    u8  = Conv2D(filters=n_filters*2, kernel_size=2, data_format=IMAGE_ORDERING,
                activation="relu", padding="same", kernel_initializer="he_normal")(up8)
    m8  = Concatenate(axis=3)([u8, c2])
    m8 = BatchNormalization()(m8)
    c8 = conv2d_block(m8, n_filters * 2, kernel_size = 3, batchnorm = batchnorm, activation=activation)
    
    ## Block9: 64, 64
    up9 = UpSampling2D(size=(2, 2),data_format=IMAGE_ORDERING, interpolation="bilinear")(c8) # 224x224x64
    u9  = Conv2D(filters=n_filters*1, kernel_size=2, data_format=IMAGE_ORDERING,
                activation="relu", padding="same", kernel_initializer="he_normal")(up9)
    m9 = Concatenate(axis=3)([u9, c1])
    m9 = BatchNormalization()(m9)
    c9 = conv2d_block(m9, n_filters * 1, kernel_size = 3, batchnorm = batchnorm, activation=activation)
    
    ## Last layers
    c10 = Conv2D(filters=nClasses, kernel_size=1, data_format=IMAGE_ORDERING)(c9)
    o = (Activation("softmax"))(c10)
    model = Model(inputs=img_input, outputs=o)

    return model
